# %% [markdown]
# <a href="https://colab.research.google.com/github/harithmote98/harith_INFO5731_Fall2021/blob/main/INFO5731_Assignment_Three_(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **INFO5731 Assignment Three**
#
# In this assignment, you are required to conduct information extraction, semantic analysis based on **the dataset you collected from assignment two**. You may use scipy and numpy package in this assignment. (Use 500 records amount all the data you collected).

# %% [markdown]
# # **Question 1: Understand N-gram**

# %% [markdown]
# (45 points). Write a python program to conduct N-gram analysis based on the dataset in your assignment two:
#
# (1) Count the frequency of all the N-grams (N=3).
#
# (2) Calculate the probabilities for all the bigrams in the dataset by using the fomular count(w2 w1) / count(w2). For example, count(really like) / count(really) = 1 / 3 = 0.33.
#
# (3) Extract all the **noun phrases** and calculate the relative probabilities of each review in terms of other reviews (abstracts, or tweets) by using the fomular frequency (noun phrase) / max frequency (noun phrase) on the whole dataset. Print out the result in a table with column name the all the noun phrases and row name as the 500 reviews (abstracts, or tweets).

# %%
# Write your code here
#installing selenium package
# !apt-get update
# !apt install chromium-chromedriver
# !cp /usr/lib/chromium-browser/chromedriver /usr/bin
# !pip install selenium
# Out:
# Ign:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Ign:2 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Get:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release [696 B]
# Hit:4 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Get:5 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release.gpg [836 B]
# Get:6 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Get:7 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease [3,626 B]
# Hit:8 http://archive.ubuntu.com/ubuntu bionic InRelease
# Hit:10 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease
# Get:11 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Get:12 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Packages [808 kB]
# Hit:13 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# Get:14 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ Packages [73.0 kB]
# Hit:15 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic InRelease
# Get:16 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [74.6 kB]
# Get:17 http://security.ubuntu.com/ubuntu bionic-security/universe amd64 Packages [1,437 kB]
# Hit:18 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease
# Get:19 http://security.ubuntu.com/ubuntu bionic-security/main amd64 Packages [2,400 kB]
# Get:20 http://security.ubuntu.com/ubuntu bionic-security/restricted amd64 Packages [633 kB]
# Get:21 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 Packages [2,217 kB]
# Get:22 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 Packages [2,837 kB]
# Fetched 10.7 MB in 4s (2,919 kB/s)
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   chromium-browser chromium-browser-l10n chromium-codecs-ffmpeg-extra
# Suggested packages:
#   webaccounts-chromium-extension unity-chromium-extension
# The following NEW packages will be installed:
#   chromium-browser chromium-browser-l10n chromium-chromedriver
#   chromium-codecs-ffmpeg-extra
# 0 upgraded, 4 newly installed, 0 to remove and 47 not upgraded.
# Need to get 94.0 MB of archives.
# After this operation, 324 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 chromium-codecs-ffmpeg-extra amd64 95.0.4638.69-0ubuntu0.18.04.1 [1,135 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 chromium-browser amd64 95.0.4638.69-0ubuntu0.18.04.1 [83.6 MB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 chromium-browser-l10n all 95.0.4638.69-0ubuntu0.18.04.1 [4,249 kB]
# Get:4 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 chromium-chromedriver amd64 95.0.4638.69-0ubuntu0.18.04.1 [4,986 kB]
# Fetched 94.0 MB in 6s (15.0 MB/s)
# Selecting previously unselected package chromium-codecs-ffmpeg-extra.
# (Reading database ... 155219 files and directories currently installed.)
# Preparing to unpack .../chromium-codecs-ffmpeg-extra_95.0.4638.69-0ubuntu0.18.04.1_amd64.deb ...
# Unpacking chromium-codecs-ffmpeg-extra (95.0.4638.69-0ubuntu0.18.04.1) ...
# Selecting previously unselected package chromium-browser.
# Preparing to unpack .../chromium-browser_95.0.4638.69-0ubuntu0.18.04.1_amd64.deb ...
# Unpacking chromium-browser (95.0.4638.69-0ubuntu0.18.04.1) ...
# Selecting previously unselected package chromium-browser-l10n.
# Preparing to unpack .../chromium-browser-l10n_95.0.4638.69-0ubuntu0.18.04.1_all.deb ...
# Unpacking chromium-browser-l10n (95.0.4638.69-0ubuntu0.18.04.1) ...
# Selecting previously unselected package chromium-chromedriver.
# Preparing to unpack .../chromium-chromedriver_95.0.4638.69-0ubuntu0.18.04.1_amd64.deb ...
# Unpacking chromium-chromedriver (95.0.4638.69-0ubuntu0.18.04.1) ...
# Setting up chromium-codecs-ffmpeg-extra (95.0.4638.69-0ubuntu0.18.04.1) ...
# Setting up chromium-browser (95.0.4638.69-0ubuntu0.18.04.1) ...
# update-alternatives: using /usr/bin/chromium-browser to provide /usr/bin/x-www-browser (x-www-browser) in auto mode
# update-alternatives: using /usr/bin/chromium-browser to provide /usr/bin/gnome-www-browser (gnome-www-browser) in auto mode
# Setting up chromium-chromedriver (95.0.4638.69-0ubuntu0.18.04.1) ...
# Setting up chromium-browser-l10n (95.0.4638.69-0ubuntu0.18.04.1) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Processing triggers for hicolor-icon-theme (0.17-2) ...
# Processing triggers for mime-support (3.60ubuntu1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1.3) ...
# /sbin/ldconfig.real: /usr/local/lib/python3.7/dist-packages/ideep4py/lib/libmkldnn.so.0 is not a symbolic link
#
# cp: '/usr/lib/chromium-browser/chromedriver' and '/usr/bin/chromedriver' are the same file
# Collecting selenium
#   Downloading selenium-4.0.0-py3-none-any.whl (954 kB)
#      |████████████████████████████████| 954 kB 9.3 MB/s
# Collecting trio~=0.17
#   Downloading trio-0.19.0-py3-none-any.whl (356 kB)
#      |████████████████████████████████| 356 kB 68.8 MB/s
# Collecting trio-websocket~=0.9
#   Downloading trio_websocket-0.9.2-py3-none-any.whl (16 kB)
# Collecting urllib3[secure]~=1.26
#   Downloading urllib3-1.26.7-py2.py3-none-any.whl (138 kB)
#      |████████████████████████████████| 138 kB 67.1 MB/s
# Collecting outcome
#   Downloading outcome-1.1.0-py2.py3-none-any.whl (9.7 kB)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.7/dist-packages (from trio~=0.17->selenium) (21.2.0)
# Collecting sniffio
#   Downloading sniffio-1.2.0-py3-none-any.whl (10 kB)
# Requirement already satisfied: idna in /usr/local/lib/python3.7/dist-packages (from trio~=0.17->selenium) (2.10)
# Requirement already satisfied: sortedcontainers in /usr/local/lib/python3.7/dist-packages (from trio~=0.17->selenium) (2.4.0)
# Collecting async-generator>=1.9
#   Downloading async_generator-1.10-py3-none-any.whl (18 kB)
# Collecting wsproto>=0.14
#   Downloading wsproto-1.0.0-py3-none-any.whl (24 kB)
# Collecting pyOpenSSL>=0.14
#   Downloading pyOpenSSL-21.0.0-py2.py3-none-any.whl (55 kB)
#      |████████████████████████████████| 55 kB 3.6 MB/s
# Collecting cryptography>=1.3.4
#   Downloading cryptography-35.0.0-cp36-abi3-manylinux_2_24_x86_64.whl (3.5 MB)
#      |████████████████████████████████| 3.5 MB 48.9 MB/s
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from urllib3[secure]~=1.26->selenium) (2021.5.30)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.7/dist-packages (from cryptography>=1.3.4->urllib3[secure]~=1.26->selenium) (1.14.6)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.7/dist-packages (from cffi>=1.12->cryptography>=1.3.4->urllib3[secure]~=1.26->selenium) (2.20)
# Requirement already satisfied: six>=1.5.2 in /usr/local/lib/python3.7/dist-packages (from pyOpenSSL>=0.14->urllib3[secure]~=1.26->selenium) (1.15.0)
# Collecting h11<1,>=0.9.0
#   Downloading h11-0.12.0-py3-none-any.whl (54 kB)
#      |████████████████████████████████| 54 kB 3.2 MB/s
# Installing collected packages: sniffio, outcome, h11, cryptography, async-generator, wsproto, urllib3, trio, pyOpenSSL, trio-websocket, selenium
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# requests 2.23.0 requires urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1, but you have urllib3 1.26.7 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# Successfully installed async-generator-1.10 cryptography-35.0.0 h11-0.12.0 outcome-1.1.0 pyOpenSSL-21.0.0 selenium-4.0.0 sniffio-1.2.0 trio-0.19.0 trio-websocket-0.9.2 urllib3-1.26.7 wsproto-1.0.0

# %% [markdown]
# **importing required packages**

# %%
from selenium import webdriver #importing selenium package
options = webdriver.ChromeOptions()
options.add_argument('-headless')
options.add_argument('-no-sandbox')
options.add_argument('-disable-dev-shm-usage')

# %% [markdown]
# **scraping the data and loading the dataframe**

# %%
from selenium.webdriver.support.ui import WebDriverWait as wait
from selenium.webdriver.common.by import By
import pandas as pd
import time

driver = webdriver.Chrome('chromedriver',options=options) #creating a driver path
link = 'https://www.imdb.com/title/tt9376612/reviews?ref_=tt_sa_3'
title_array = [] 
review_array = []
driver.get(link)
for num in range(45): #giving range 45 to get all reviews
  driver.find_element_by_class_name("ipl-load-more__button").click() #giving class name as ipl-load-mote__button to get all pages
  time.sleep(5)
  listOfTitle = driver.find_elements(By.CLASS_NAME, "title")#giving class title to get the titles
  listOfReviews = driver.find_elements(By.CLASS_NAME, "text")#giving class text to get the text
for ele, sub_ele in zip(listOfTitle, listOfReviews):#writing a for loop to append each review and title into the empty arrays created
      title_array.append((ele.text).replace('\n',''))
      review_array.append(sub_ele.text)
df = pd.DataFrame(list(zip(title_array, review_array)), columns =['Title', 'Review'])
print("Length of data frame is {0}".format(len(df)))
df
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:12: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   if sys.path[0] == '':
# Length of data frame is 1150
#                                           Title                                             Review
# 0                                    Next Phase
# 1     Shang-Chi and the Legend of the Ten Rings
# 2                                       Bus Boy
# 3                        Precious ... ten times  Of course I am just riffing off, teasing and m...
# 4                                          Wow!  I was not expecting that, I had visions of a f...
# ...                                         ...                                                ...
# 1145             Unique Marvel film is a blast!  Having worked on this film's visual effects, I...
# 1146                                     Superb  Absolutely fantastic! Just don't miss it on bi...
# 1147                A great addition to the MCU  By far my favourite Marvel Movie of all time. ...
# 1148                            Beautiful movie
# 1149  Marvel is trembling the theaters again!!!  Shang-Chi and the Legend of the Ten Rings is t...
#
# [1150 rows x 2 columns]

# %%
import nltk
nltk.download()
# Out:
# NLTK Downloader
# ---------------------------------------------------------------------------
#     d) Download   l) List    u) Update   c) Config   h) Help   q) Quit
# ---------------------------------------------------------------------------
# Downloader> d
#
# Download which package (l=list; x=cancel)?
#   Identifier> all
#     Downloading collection 'all'
#        |
#        | Downloading package abc to /root/nltk_data...
#        |   Unzipping corpora/abc.zip.
#        | Downloading package alpino to /root/nltk_data...
#        |   Unzipping corpora/alpino.zip.
#        | Downloading package biocreative_ppi to /root/nltk_data...
#        |   Unzipping corpora/biocreative_ppi.zip.
#        | Downloading package brown to /root/nltk_data...
#        |   Unzipping corpora/brown.zip.
#        | Downloading package brown_tei to /root/nltk_data...
#        |   Unzipping corpora/brown_tei.zip.
#        | Downloading package cess_cat to /root/nltk_data...
#        |   Unzipping corpora/cess_cat.zip.
#        | Downloading package cess_esp to /root/nltk_data...
#        |   Unzipping corpora/cess_esp.zip.
#        | Downloading package chat80 to /root/nltk_data...
#        |   Unzipping corpora/chat80.zip.
#        | Downloading package city_database to /root/nltk_data...
#        |   Unzipping corpora/city_database.zip.
#        | Downloading package cmudict to /root/nltk_data...
#        |   Unzipping corpora/cmudict.zip.
#        | Downloading package comparative_sentences to
#        |     /root/nltk_data...
#        |   Unzipping corpora/comparative_sentences.zip.
#        | Downloading package comtrans to /root/nltk_data...
#        | Downloading package conll2000 to /root/nltk_data...
#        |   Unzipping corpora/conll2000.zip.
#        | Downloading package conll2002 to /root/nltk_data...
#        |   Unzipping corpora/conll2002.zip.
#        | Downloading package conll2007 to /root/nltk_data...
#        | Downloading package crubadan to /root/nltk_data...
#        |   Unzipping corpora/crubadan.zip.
#        | Downloading package dependency_treebank to /root/nltk_data...
#        |   Unzipping corpora/dependency_treebank.zip.
#        | Downloading package dolch to /root/nltk_data...
#        |   Unzipping corpora/dolch.zip.
#        | Downloading package europarl_raw to /root/nltk_data...
#        |   Unzipping corpora/europarl_raw.zip.
#        | Downloading package floresta to /root/nltk_data...
#        |   Unzipping corpora/floresta.zip.
#        | Downloading package framenet_v15 to /root/nltk_data...
#        |   Unzipping corpora/framenet_v15.zip.
#        | Downloading package framenet_v17 to /root/nltk_data...
#        |   Unzipping corpora/framenet_v17.zip.
#        | Downloading package gazetteers to /root/nltk_data...
#        |   Unzipping corpora/gazetteers.zip.
#        | Downloading package genesis to /root/nltk_data...
#        |   Unzipping corpora/genesis.zip.
#        | Downloading package gutenberg to /root/nltk_data...
#        |   Unzipping corpora/gutenberg.zip.
#        | Downloading package ieer to /root/nltk_data...
#        |   Unzipping corpora/ieer.zip.
#        | Downloading package inaugural to /root/nltk_data...
#        |   Unzipping corpora/inaugural.zip.
#        | Downloading package indian to /root/nltk_data...
#        |   Unzipping corpora/indian.zip.
#        | Downloading package jeita to /root/nltk_data...
#        | Downloading package kimmo to /root/nltk_data...
#        |   Unzipping corpora/kimmo.zip.
#        | Downloading package knbc to /root/nltk_data...
#        | Downloading package lin_thesaurus to /root/nltk_data...
#        |   Unzipping corpora/lin_thesaurus.zip.
#        | Downloading package mac_morpho to /root/nltk_data...
#        |   Unzipping corpora/mac_morpho.zip.
#        | Downloading package machado to /root/nltk_data...
#        | Downloading package masc_tagged to /root/nltk_data...
#        | Downloading package moses_sample to /root/nltk_data...
#        |   Unzipping models/moses_sample.zip.
#        | Downloading package movie_reviews to /root/nltk_data...
#        |   Unzipping corpora/movie_reviews.zip.
#        | Downloading package names to /root/nltk_data...
#        |   Unzipping corpora/names.zip.
#        | Downloading package nombank.1.0 to /root/nltk_data...
#        | Downloading package nps_chat to /root/nltk_data...
#        |   Unzipping corpora/nps_chat.zip.
#        | Downloading package omw to /root/nltk_data...
#        |   Unzipping corpora/omw.zip.
#        | Downloading package opinion_lexicon to /root/nltk_data...
#        |   Unzipping corpora/opinion_lexicon.zip.
#        | Downloading package paradigms to /root/nltk_data...
#        |   Unzipping corpora/paradigms.zip.
#        | Downloading package pil to /root/nltk_data...
#        |   Unzipping corpora/pil.zip.
#        | Downloading package pl196x to /root/nltk_data...
#        |   Unzipping corpora/pl196x.zip.
#        | Downloading package ppattach to /root/nltk_data...
#        |   Unzipping corpora/ppattach.zip.
#        | Downloading package problem_reports to /root/nltk_data...
#        |   Unzipping corpora/problem_reports.zip.
#        | Downloading package propbank to /root/nltk_data...
#        | Downloading package ptb to /root/nltk_data...
#        |   Unzipping corpora/ptb.zip.
#        | Downloading package product_reviews_1 to /root/nltk_data...
#        |   Unzipping corpora/product_reviews_1.zip.
#        | Downloading package product_reviews_2 to /root/nltk_data...
#        |   Unzipping corpora/product_reviews_2.zip.
#        | Downloading package pros_cons to /root/nltk_data...
#        |   Unzipping corpora/pros_cons.zip.
#        | Downloading package qc to /root/nltk_data...
#        |   Unzipping corpora/qc.zip.
#        | Downloading package reuters to /root/nltk_data...
#        | Downloading package rte to /root/nltk_data...
#        |   Unzipping corpora/rte.zip.
#        | Downloading package semcor to /root/nltk_data...
#        | Downloading package senseval to /root/nltk_data...
#        |   Unzipping corpora/senseval.zip.
#        | Downloading package sentiwordnet to /root/nltk_data...
#        |   Unzipping corpora/sentiwordnet.zip.
#        | Downloading package sentence_polarity to /root/nltk_data...
#        |   Unzipping corpora/sentence_polarity.zip.
#        | Downloading package shakespeare to /root/nltk_data...
#        |   Unzipping corpora/shakespeare.zip.
#        | Downloading package sinica_treebank to /root/nltk_data...
#        |   Unzipping corpora/sinica_treebank.zip.
#        | Downloading package smultron to /root/nltk_data...
#        |   Unzipping corpora/smultron.zip.
#        | Downloading package state_union to /root/nltk_data...
#        |   Unzipping corpora/state_union.zip.
#        | Downloading package stopwords to /root/nltk_data...
#        |   Package stopwords is already up-to-date!
#        | Downloading package subjectivity to /root/nltk_data...
#        |   Unzipping corpora/subjectivity.zip.
#        | Downloading package swadesh to /root/nltk_data...
#        |   Unzipping corpora/swadesh.zip.
#        | Downloading package switchboard to /root/nltk_data...
#        |   Unzipping corpora/switchboard.zip.
#        | Downloading package timit to /root/nltk_data...
#        |   Unzipping corpora/timit.zip.
#        | Downloading package toolbox to /root/nltk_data...
#        |   Unzipping corpora/toolbox.zip.
#        | Downloading package treebank to /root/nltk_data...
#        |   Unzipping corpora/treebank.zip.
#        | Downloading package twitter_samples to /root/nltk_data...
#        |   Unzipping corpora/twitter_samples.zip.
#        | Downloading package udhr to /root/nltk_data...
#        |   Unzipping corpora/udhr.zip.
#        | Downloading package udhr2 to /root/nltk_data...
#        |   Unzipping corpora/udhr2.zip.
#        | Downloading package unicode_samples to /root/nltk_data...
#        |   Unzipping corpora/unicode_samples.zip.
#        | Downloading package universal_treebanks_v20 to
#        |     /root/nltk_data...
#        | Downloading package verbnet to /root/nltk_data...
#        |   Unzipping corpora/verbnet.zip.
#        | Downloading package verbnet3 to /root/nltk_data...
#        |   Unzipping corpora/verbnet3.zip.
#        | Downloading package webtext to /root/nltk_data...
#        |   Unzipping corpora/webtext.zip.
#        | Downloading package wordnet to /root/nltk_data...
#        |   Unzipping corpora/wordnet.zip.
#        | Downloading package wordnet31 to /root/nltk_data...
#        |   Unzipping corpora/wordnet31.zip.
#        | Downloading package wordnet_ic to /root/nltk_data...
#        |   Unzipping corpora/wordnet_ic.zip.
#        | Downloading package words to /root/nltk_data...
#        |   Unzipping corpora/words.zip.
#        | Downloading package ycoe to /root/nltk_data...
#        |   Unzipping corpora/ycoe.zip.
#        | Downloading package rslp to /root/nltk_data...
#        |   Unzipping stemmers/rslp.zip.
#        | Downloading package maxent_treebank_pos_tagger to
#        |     /root/nltk_data...
#        |   Unzipping taggers/maxent_treebank_pos_tagger.zip.
#        | Downloading package universal_tagset to /root/nltk_data...
#        |   Unzipping taggers/universal_tagset.zip.
#        | Downloading package maxent_ne_chunker to /root/nltk_data...
#        |   Unzipping chunkers/maxent_ne_chunker.zip.
#        | Downloading package punkt to /root/nltk_data...
#        |   Package punkt is already up-to-date!
#        | Downloading package book_grammars to /root/nltk_data...
#        |   Unzipping grammars/book_grammars.zip.
#        | Downloading package sample_grammars to /root/nltk_data...
#        |   Unzipping grammars/sample_grammars.zip.
#        | Downloading package spanish_grammars to /root/nltk_data...
#        |   Unzipping grammars/spanish_grammars.zip.
#        | Downloading package basque_grammars to /root/nltk_data...
#        |   Unzipping grammars/basque_grammars.zip.
#        | Downloading package large_grammars to /root/nltk_data...
#        |   Unzipping grammars/large_grammars.zip.
#        | Downloading package tagsets to /root/nltk_data...
#        |   Unzipping help/tagsets.zip.
#        | Downloading package snowball_data to /root/nltk_data...
#        | Downloading package bllip_wsj_no_aux to /root/nltk_data...
#        |   Unzipping models/bllip_wsj_no_aux.zip.
#        | Downloading package word2vec_sample to /root/nltk_data...
#        |   Unzipping models/word2vec_sample.zip.
#        | Downloading package panlex_swadesh to /root/nltk_data...
#        | Downloading package mte_teip5 to /root/nltk_data...
#        |   Unzipping corpora/mte_teip5.zip.
#        | Downloading package averaged_perceptron_tagger to
#        |     /root/nltk_data...
#        |   Unzipping taggers/averaged_perceptron_tagger.zip.
#        | Downloading package averaged_perceptron_tagger_ru to
#        |     /root/nltk_data...
#        |   Unzipping taggers/averaged_perceptron_tagger_ru.zip.
#        | Downloading package perluniprops to /root/nltk_data...
#        |   Unzipping misc/perluniprops.zip.
#        | Downloading package nonbreaking_prefixes to
#        |     /root/nltk_data...
#        |   Unzipping corpora/nonbreaking_prefixes.zip.
#        | Downloading package vader_lexicon to /root/nltk_data...
#        | Downloading package porter_test to /root/nltk_data...
#        |   Unzipping stemmers/porter_test.zip.
#        | Downloading package wmt15_eval to /root/nltk_data...
#        |   Unzipping models/wmt15_eval.zip.
#        | Downloading package mwa_ppdb to /root/nltk_data...
#        |   Unzipping misc/mwa_ppdb.zip.
#        |
#      Done downloading collection all
#
# ---------------------------------------------------------------------------
#     d) Download   l) List    u) Update   c) Config   h) Help   q) Quit
# ---------------------------------------------------------------------------
# Downloader> q
# True

# %% [markdown]
# **converting into lower case**

# %%
df['Lower Case'] = df['Review'].apply(lambda x: " ".join(x.lower() for x in x.split()))

# %% [markdown]
# **removing punctuation**

# %%
df['Removal of Punctuation'] = df['Lower Case'].str.replace('[^\w\s]','')

# %% [markdown]
# **removing special characters**

# %%
import re
df['Removal of Special Characters'] = df['Removal of Punctuation'].apply(lambda x: ''.join(re.sub(r"[^a-zA-Z0-9]+", ' ', charctr) for charctr in x ))

# %% [markdown]
# **removing stopwords**

# %%
from nltk.corpus import stopwords
stop = stopwords.words('english')
df['Stopwords Removal'] = df['Removal of Punctuation'].apply(lambda x: " ".join(x for x in x.split() if x not in stop))

# %% [markdown]
# **Spelling correction**

# %%
from textblob import TextBlob
df['Spelling Correction'] = df['Stopwords Removal'].apply(lambda x: str(TextBlob(x).correct()))

# %% [markdown]
# **Tokenization**

# %%
import nltk
nltk.download('punkt')
df['Tokenization'] = df['Spelling Correction'].apply(lambda x: TextBlob(x).words)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# **Stemming**

# %%
from nltk.stem import PorterStemmer
st = PorterStemmer()
df['After Stemming'] = df['Tokenization'].apply(lambda x: " ".join([st.stem(word) for word in x]))

# %% [markdown]
# **Lemmatization**

# %%
from textblob import Word
import nltk
nltk.download('wordnet')

df['After Lemmatization'] = df['After Stemming'].apply(lambda x: " ".join([Word(word).lemmatize() for word in x.split()]))
df.to_csv('/content/sample_data/reviwes.csv',index=False)
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %% [markdown]
# **trigrams**

# %%
import itertools
import collections
from nltk import ngrams
from nltk.tokenize import word_tokenize

words_sentence = []
for sentence in df['After Lemmatization']:
  words_sentence.append(word_tokenize(sentence))
aftercleaning = [x for x in words_sentence if x != []]
iterations = list(itertools.chain.from_iterable(aftercleaning))

# %%
tri_grams = nltk.trigrams(iterations)
frequency_dist = nltk.FreqDist(tri_grams)
frequency_dist
# Out:
# FreqDist({('cours', 'rise', 'tea'): 1,
#           ('rise', 'tea', 'make'): 1,
#           ('tea', 'make', 'fun'): 1,
#           ('make', 'fun', 'certain'): 1,
#           ('fun', 'certain', 'thing'): 1,
#           ('certain', 'thing', 'summari'): 1,
#           ('thing', 'summari', 'line'): 1,
#           ('summari', 'line', 'though'): 1,
#           ('line', 'though', 'truth'): 1,
#           ('though', 'truth', 'especi'): 1,
#           ('truth', 'especi', 'consid'): 1,
#           ('especi', 'consid', 'last'): 1,
#           ('consid', 'last', 'third'): 1,
#           ('last', 'third', 'movi'): 2,
#           ('third', 'movi', 'quit'): 1,
#           ('movi', 'quit', 'fantast'): 1,
#           ('quit', 'fantast', 'put'): 1,
#           ('fantast', 'put', 'intend'): 1,
#           ('put', 'intend', 'much'): 1,
#           ('intend', 'much', 'may'): 1,
#           ('much', 'may', 'seen'): 1,
#           ('may', 'seen', 'bu'): 1,
#           ('seen', 'bu', 'scene'): 1,
#           ('bu', 'scene', 'alreadi'): 1,
#           ('scene', 'alreadi', 'imagin'): 1,
#           ('alreadi', 'imagin', 'mani'): 1,
#           ('imagin', 'mani', 'time'): 1,
#           ('mani', 'time', 'still'): 1,
#           ('time', 'still', 'quit'): 1,
#           ('still', 'quit', 'highlight'): 1,
#           ('quit', 'highlight', 'work'): 1,
#           ('highlight', 'work', 'wonder'): 1,
#           ('work', 'wonder', 'even'): 1,
#           ('wonder', 'even', 'trailerteas'): 1,
#           ('even', 'trailerteas', 'reveal'): 1,
#           ('trailerteas', 'reveal', 'plot'): 1,
#           ('reveal', 'plot', 'charact'): 1,
#           ('plot', 'charact', 'movi'): 1,
#           ('charact', 'movi', 'abl'): 1,
#           ('movi', 'abl', 'watch'): 1,
#           ('abl', 'watch', 'max'): 1,
#           ('watch', 'max', 'screen'): 1,
#           ('max', 'screen', 'let'): 1,
#           ('screen', 'let', 'tell'): 1,
#           ('let', 'tell', 'now'): 1,
#           ('tell', 'now', 'also'): 1,
#           ('now', 'also', 'now'): 1,
#           ('also', 'now', 'much'): 1,
#           ('now', 'much', 'respect'): 1,
#           ('much', 'respect', 'marvel'): 1,
#           ('respect', 'marvel', 'beig'): 1,
#           ('marvel', 'beig', 'anyon'): 1,
#           ('beig', 'anyon', 'involv'): 1,
#           ('anyon', 'involv', 'dare'): 1,
#           ('involv', 'dare', 'make'): 1,
#           ('dare', 'make', 'first'): 1,
#           ('make', 'first', 'ten'): 1,
#           ('first', 'ten', 'minut'): 1,
#           ('ten', 'minut', 'chine'): 1,
#           ('minut', 'chine', 'throw'): 1,
#           ('chine', 'throw', 'lot'): 1,
#           ('throw', 'lot', 'chine'): 1,
#           ('lot', 'chine', 'term'): 1,
#           ('chine', 'term', 'slang'): 1,
#           ('term', 'slang', 'well'): 1,
#           ('slang', 'well', 'throughout'): 1,
#           ('well', 'throughout', 'give'): 1,
#           ('throughout', 'give', 'touch'): 1,
#           ('give', 'touch', 'authent'): 1,
#           ('touch', 'authent', 'immigr'): 1,
#           ('authent', 'immigr', 'america'): 1,
#           ('immigr', 'america', 'anywher'): 1,
#           ('america', 'anywher', 'el'): 1,
#           ('anywher', 'el', 'world'): 1,
#           ('el', 'world', 'grew'): 1,
#           ('world', 'grew', 'greek'): 1,
#           ('grew', 'greek', 'germanenglish'): 1,
#           ('greek', 'germanenglish', 'also'): 1,
#           ('germanenglish', 'also', 'nice'): 1,
#           ('also', 'nice', 'prone'): 1,
#           ('nice', 'prone', 'sarcast'): 1,
#           ('prone', 'sarcast', 'realli'): 1,
#           ('sarcast', 'realli', 'think'): 1,
#           ('realli', 'think', 'good'): 1,
#           ('think', 'good', 'thing'): 1,
#           ('good', 'thing', 'major'): 1,
#           ('thing', 'major', 'big'): 1,
#           ('major', 'big', 'represent'): 1,
#           ('big', 'represent', 'especi'): 1,
#           ('represent', 'especi', 'nowaday'): 1,
#           ('especi', 'nowaday', 'antiasian'): 1,
#           ('nowaday', 'antiasian', 'hatecrim'): 1,
#           ('antiasian', 'hatecrim', 'rise'): 1,
#           ('hatecrim', 'rise', 'peopl'): 1,
#           ('rise', 'peopl', 'blame'): 1,
#           ('peopl', 'blame', 'china'): 1,
#           ('blame', 'china', 'peopl'): 1,
#           ('china', 'peopl', 'china'): 1,
#           ('peopl', 'china', 'viru'): 1,
#           ('china', 'viru', 'movi'): 1,
#           ('viru', 'movi', 'topic'): 1,
#           ('movi', 'topic', 'entertain'): 1,
#           ('topic', 'entertain', 'everi'): 1,
#           ('entertain', 'everi', 'promo'): 1,
#           ('everi', 'promo', 'interview'): 1,
#           ('promo', 'interview', 'actor'): 1,
#           ('interview', 'actor', 'involv'): 1,
#           ('actor', 'involv', 'someth'): 1,
#           ('involv', 'someth', 'mention'): 1,
#           ('someth', 'mention', 'good'): 1,
#           ('mention', 'good', 'good'): 1,
#           ('good', 'good', 'u'): 1,
#           ('good', 'u', 'made'): 1,
#           ('u', 'made', 'bit'): 1,
#           ('made', 'bit', 'base'): 1,
#           ('bit', 'base', 'come'): 1,
#           ('base', 'come', 'you'): 1,
#           ('come', 'you', 'get'): 1,
#           ('you', 'get', 'pure'): 1,
#           ('get', 'pure', 'theatric'): 1,
#           ('pure', 'theatric', 'releas'): 1,
#           ('theatric', 'releas', 'instead'): 1,
#           ('releas', 'instead', 'black'): 1,
#           ('instead', 'black', 'widow'): 1,
#           ('black', 'widow', 'treatment'): 1,
#           ('widow', 'treatment', 'also'): 1,
#           ('treatment', 'also', 'avail'): 1,
#           ('also', 'avail', 'dinner'): 1,
#           ('avail', 'dinner', 'plu'): 1,
#           ('dinner', 'plu', 'cinema'): 1,
#           ('plu', 'cinema', 'time'): 1,
#           ('cinema', 'time', 'issu'): 1,
#           ('time', 'issu', 'come'): 1,
#           ('issu', 'come', 'watch'): 1,
#           ('come', 'watch', 'big'): 1,
#           ('watch', 'big', 'screen'): 2,
#           ('big', 'screen', 'disappoint'): 1,
#           ('screen', 'disappoint', 'wait'): 1,
#           ('disappoint', 'wait', 'stuff'): 1,
#           ('wait', 'stuff', 'drop'): 1,
#           ('stuff', 'drop', 'especi'): 1,
#           ('drop', 'especi', 'mid'): 1,
#           ('especi', 'mid', 'credit'): 1,
#           ('mid', 'credit', 'scene'): 3,
#           ('credit', 'scene', 'tea'): 1,
#           ('scene', 'tea', 'credit'): 1,
#           ('tea', 'credit', 'scene'): 1,
#           ('credit', 'scene', 'might'): 1,
#           ('scene', 'might', 'also'): 1,
#           ('might', 'also', 'hint'): 1,
#           ('also', 'hint', 'someth'): 1,
#           ('hint', 'someth', 'bigger'): 1,
#           ('someth', 'bigger', 'tea'): 1,
#           ('bigger', 'tea', 'midway'): 1,
#           ('tea', 'midway', 'credit'): 1,
#           ('midway', 'credit', 'actual'): 1,
#           ('credit', 'actual', 'almost'): 1,
#           ('actual', 'almost', 'begin'): 1,
#           ('almost', 'begin', 'honest'): 1,
#           ('begin', 'honest', 'sit'): 1,
#           ('honest', 'sit', 'back'): 1,
#           ('sit', 'back', 'enjoy'): 1,
#           ('back', 'enjoy', 'movi'): 1,
#           ('enjoy', 'movi', 'realli'): 2,
#           ('movi', 'realli', 'funni'): 1,
#           ('realli', 'funni', 'charact'): 1,
#           ('funni', 'charact', 'quit'): 1,
#           ('charact', 'quit', 'familiar'): 1,
#           ('quit', 'familiar', 'face'): 1,
#           ('familiar', 'face', 'you'): 1,
#           ('face', 'you', 'previou'): 1,
#           ('you', 'previou', 'entri'): 1,
#           ('previou', 'entri', 'also'): 1,
#           ('entri', 'also', 'asia'): 1,
#           ('also', 'asia', 'cinema'): 1,
#           ('asia', 'cinema', 'well'): 1,
#           ('cinema', 'well', 'done'): 1,
#           ('well', 'done', 'expect'): 1,
#           ('done', 'expect', 'vision'): 1,
#           ('expect', 'vision', 'film'): 1,
#           ('vision', 'film', 'along'): 1,
#           ('film', 'along', 'line'): 1,
#           ('along', 'line', 'snake'): 1,
#           ('line', 'snake', 'eye'): 1,
#           ('snake', 'eye', 'date'): 1,
#           ('eye', 'date', 'babel'): 1,
#           ('date', 'babel', 'four'): 1,
#           ('babel', 'four', 'cours'): 1,
#           ('four', 'cours', 'banquet'): 1,
#           ('cours', 'banquet', 'fast'): 1,
#           ('banquet', 'fast', 'pace'): 1,
#           ('fast', 'pace', 'energet'): 1,
#           ('pace', 'energet', 'relentless'): 1,
#           ('energet', 'relentless', 'particularli'): 1,
#           ('relentless', 'particularli', 'gene'): 1,
#           ('particularli', 'gene', 'normal'): 1,
#           ('gene', 'normal', 'go'): 1,
#           ('normal', 'go', 'enjoy'): 1,
#           ('go', 'enjoy', 'love'): 1,
#           ('enjoy', 'love', 'everi'): 1,
#           ('love', 'everi', 'second'): 1,
#           ('everi', 'second', 'visual'): 1,
#           ('second', 'visual', 'masterpiec'): 1,
#           ('visual', 'masterpiec', 'superb'): 1,
#           ('masterpiec', 'superb', 'act'): 1,
#           ('superb', 'act', 'terrif'): 1,
#           ('act', 'terrif', 'music'): 1,
#           ('terrif', 'music', 'produc'): 1,
#           ('music', 'produc', 'magic'): 1,
#           ('produc', 'magic', 'way'): 1,
#           ('magic', 'way', 'stun'): 1,
#           ('way', 'stun', 'plan'): 1,
#           ('stun', 'plan', 'see'): 1,
#           ('plan', 'see', 'understand'): 1,
#           ('see', 'understand', 'bit'): 1,
#           ('understand', 'bit', 'littl'): 1,
#           ('bit', 'littl', 'go'): 1,
#           ('littl', 'go', 'watch'): 1,
#           ('go', 'watch', 'you'): 1,
#           ('watch', 'you', 'love'): 1,
#           ('you', 'love', '910'): 1,
#           ('love', '910', 'find'): 1,
#           ('910', 'find', 'film'): 1,
#           ('find', 'film', 'engag'): 1,
#           ('film', 'engag', 'start'): 1,
#           ('engag', 'start', 'finish'): 2,
#           ('start', 'finish', 'couldn'): 1,
#           ('finish', 'couldn', 'get'): 1,
#           ('couldn', 'get', 'eye'): 1,
#           ('get', 'eye', 'screen'): 1,
#           ('eye', 'screen', 'king'): 1,
#           ('screen', 'king', 'ff'): 1,
#           ('king', 'ff', 'good'): 2,
#           ('ff', 'good', 'visual'): 1,
#           ('good', 'visual', 'effect'): 1,
#           ('visual', 'effect', 'wonder'): 1,
#           ('effect', 'wonder', 'enjoy'): 1,
#           ('wonder', 'enjoy', 'everi'): 1,
#           ('enjoy', 'everi', 'second'): 1,
#           ('everi', 'second', 'film'): 1,
#           ('second', 'film', 'enjoy'): 1,
#           ('film', 'enjoy', 'seri'): 1,
#           ('enjoy', 'seri', 'long'): 1,
#           ('seri', 'long', 'kari'): 1,
#           ('long', 'kari', 'film'): 1,
#           ('kari', 'film', 'great'): 1,
#           ('film', 'great', 'see'): 1,
#           ('great', 'see', 'star'): 1,
#           ('see', 'star', 'mani'): 1,
#           ('star', 'mani', 'classic'): 1,
#           ('mani', 'classic', 'featur'): 1,
#           ('classic', 'featur', 'toni'): 1,
#           ('featur', 'toni', 'lung'): 1,
#           ('toni', 'lung', 'featur'): 1,
#           ('lung', 'featur', 'superior'): 1,
#           ('featur', 'superior', 'fantasi'): 1,
#           ('superior', 'fantasi', 'adventur'): 1,
#           ('fantasi', 'adventur', 'man'): 1,
#           ('adventur', 'man', 'magic'): 1,
#           ('man', 'magic', 'allpow'): 1,
#           ('magic', 'allpow', 'ten'): 1,
#           ('allpow', 'ten', 'ring'): 2,
#           ('ten', 'ring', 'two'): 1,
#           ('ring', 'two', 'estrang'): 1,
#           ('two', 'estrang', 'child'): 1,
#           ('estrang', 'child', 'son'): 1,
#           ('child', 'son', 'shan'): 1,
#           ('son', 'shan', 'situ'): 1,
#           ('shan', 'situ', 'lie'): 5,
#           ('situ', 'lie', 'live'): 3,
#           ('lie', 'live', 'alterc'): 1,
#           ('live', 'alterc', 'heavier'): 1,
#           ('alterc', 'heavier', 'san'): 1,
#           ('heavier', 'san', 'francisco'): 1,
#           ('san', 'francisco', 'bu'): 3,
#           ('francisco', 'bu', 'realis'): 1,
#           ('bu', 'realis', 'impend'): 1,
#           ('realis', 'impend', 'danger'): 1,
#           ('impend', 'danger', 'seek'): 1,
#           ('danger', 'seek', 'independ'): 1,
#           ('seek', 'independ', 'mind'): 1,
#           ('independ', 'mind', 'sister'): 1,
#           ('mind', 'sister', 'know'): 1,
#           ('sister', 'know', 'famili'): 1,
#           ('know', 'famili', 'somewhat'): 1,
#           ('famili', 'somewhat', 'unwillingli'): 1,
#           ('somewhat', 'unwillingli', 'reunit'): 1,
#           ('unwillingli', 'reunit', 'work'): 1,
#           ('reunit', 'work', 'togeth'): 1,
#           ('work', 'togeth', 'rescu'): 1,
#           ('togeth', 'rescu', 'late'): 1,
#           ('rescu', 'late', 'lament'): 1,
#           ('late', 'lament', 'mother'): 1,
#           ('lament', 'mother', 'clutch'): 1,
#           ('mother', 'clutch', 'evil'): 1,
#           ('clutch', 'evil', 'protect'): 1,
#           ('evil', 'protect', 'benign'): 1,
#           ('protect', 'benign', 'societi'): 1,
#           ('benign', 'societi', 'led'): 1,
#           ('societi', 'led', 'mitchel'): 1,
#           ('led', 'mitchel', 'yeah'): 1,
#           ('mitchel', 'yeah', 'honest'): 1,
#           ('yeah', 'honest', 'stori'): 1,
#           ('honest', 'stori', 'isn'): 1,
#           ('stori', 'isn', 'best'): 1,
#           ('isn', 'best', 'actual'): 1,
#           ('best', 'actual', 'littl'): 1,
#           ('actual', 'littl', 'bit'): 1,
#           ('littl', 'bit', 'simpl'): 1,
#           ('bit', 'simpl', 'predict'): 1,
#           ('simpl', 'predict', 'said'): 1,
#           ('predict', 'said', 'howev'): 1,
#           ('said', 'howev', 'characteris'): 1,
#           ('howev', 'characteris', 'engag'): 1,
#           ('characteris', 'engag', 'action'): 1,
#           ('engag', 'action', 'scene'): 2,
#           ('action', 'scene', 'well'): 2,
#           ('scene', 'well', 'stage'): 1,
#           ('well', 'stage', 'pace'): 1,
#           ('stage', 'pace', 'interest'): 1,
#           ('pace', 'interest', 'underli'): 1,
#           ('interest', 'underli', 'premis'): 1,
#           ('underli', 'premis', 'resolut'): 1,
#           ('premis', 'resolut', 'planet'): 1,
#           ('resolut', 'planet', 'appear'): 1,
#           ('planet', 'appear', 'fight'): 1,
#           ('appear', 'fight', 'back'): 1,
#           ('fight', 'back', 'mankind'): 1,
#           ('back', 'mankind', 'accumul'): 1,
#           ('mankind', 'accumul', 'indiffer'): 1,
#           ('accumul', 'indiffer', 'elysian'): 1,
#           ('indiffer', 'elysian', 'utopian'): 1,
#           ('elysian', 'utopian', 'x'): 1,
#           ('utopian', 'x', 'went'): 1,
#           ('x', 'went', 'lung'): 1,
#           ('went', 'lung', 'must'): 1,
#           ('lung', 'must', 'invad'): 1,
#           ('must', 'invad', 'rescu'): 1,
#           ('invad', 'rescu', 'wife'): 1,
#           ('rescu', 'wife', 'symbol'): 1,
#           ('wife', 'symbol', 'unspoilt'): 1,
#           ('symbol', 'unspoilt', 'element'): 1,
#           ('unspoilt', 'element', 'planet'): 1,
#           ('element', 'planet', 'intent'): 1,
#           ('planet', 'intent', 'roll'): 1,
#           ('intent', 'roll', 'peaceabl'): 1,
#           ('roll', 'peaceabl', 'whilst'): 1,
#           ('peaceabl', 'whilst', 'impos'): 1,
#           ('whilst', 'impos', 'product'): 1,
#           ('impos', 'product', 'standard'): 1,
#           ('product', 'standard', 'typic'): 1,
#           ('standard', 'typic', 'high'): 1,
#           ('typic', 'high', 'plenti'): 1,
#           ('high', 'plenti', 'cut'): 1,
#           ('plenti', 'cut', 'danger'): 1,
#           ('cut', 'danger', 'beauti'): 1,
#           ('danger', 'beauti', 'suit'): 1,
#           ('beauti', 'suit', 'plea'): 1,
#           ('suit', 'plea', 'age'): 1,
#           ('plea', 'age', 'also'): 1,
#           ('age', 'also', 'quit'): 1,
#           ('also', 'quit', 'fun'): 1,
#           ('quit', 'fun', 'seri'): 1,
#           ('fun', 'seri', 'scene'): 1,
#           ('seri', 'scene', 'sir'): 1,
#           ('scene', 'sir', 'ben'): 1,
#           ('sir', 'ben', 'dingley'): 1,
#           ('ben', 'dingley', 'liverpudlian'): 1,
#           ('dingley', 'liverpudlian', 'poet'): 1,
#           ('liverpudlian', 'poet', 'mayb'): 1,
#           ('poet', 'mayb', 'accent'): 1,
#           ('mayb', 'accent', 'isn'): 1,
#           ('accent', 'isn', 'best'): 1,
#           ('isn', 'best', 'stylish'): 1,
#           ('best', 'stylish', 'draft'): 1,
#           ('stylish', 'draft', 'final'): 1,
#           ('draft', 'final', 'told'): 1,
#           ('final', 'told', 'thoroughli'): 1,
#           ('told', 'thoroughli', 'entertain'): 1,
#           ('thoroughli', 'entertain', 'watch'): 1,
#           ('entertain', 'watch', 'two'): 1,
#           ('watch', 'two', 'hour'): 1,
#           ('two', 'hour', 'fli'): 1,
#           ('hour', 'fli', 'ten'): 1,
#           ('fli', 'ten', 'year'): 1,
#           ('ten', 'year', 'sinc'): 1,
#           ('year', 'sinc', 'shangchiliu'): 1,
#           ('sinc', 'shangchiliu', 'charm'): 1,
#           ('shangchiliu', 'charm', 'stood'): 1,
#           ('charm', 'stood', 'last'): 1,
#           ('stood', 'last', 'saw'): 1,
#           ('last', 'saw', 'father'): 1,
#           ('saw', 'father', 'leader'): 1,
#           ('father', 'leader', 'crimin'): 1,
#           ('leader', 'crimin', 'empir'): 2,
#           ('crimin', 'empir', 'ten'): 1,
#           ('empir', 'ten', 'ring'): 1,
#           ('ten', 'ring', 'wenwuleung'): 1,
#           ('ring', 'wenwuleung', 'charismat'): 1,
#           ('wenwuleung', 'charismat', 'enough'): 1,
#           ('charismat', 'enough', 'feel'): 1,
#           ('enough', 'feel', 'lot'): 1,
#           ('feel', 'lot', 'empti'): 1,
#           ('lot', 'empti', 'even'): 1,
#           ('empti', 'even', 'terribl'): 1,
#           ('even', 'terribl', 'thing'): 1,
#           ('terribl', 'thing', 'desper'): 1,
#           ('thing', 'desper', 'want'): 1,
#           ('desper', 'want', 'stop'): 1,
#           ('want', 'stop', 'also'): 1,
#           ('stop', 'also', 'last'): 1,
#           ('also', 'last', 'spent'): 1,
#           ('last', 'spent', 'time'): 1,
#           ('spent', 'time', 'sister'): 1,
#           ('time', 'sister', 'xialingzhang'): 1,
#           ('sister', 'xialingzhang', 'adam'): 1,
#           ('xialingzhang', 'adam', 'deserv'): 1,
#           ('adam', 'deserv', 'screen'): 1,
#           ('deserv', 'screen', 'time'): 1,
#           ('screen', 'time', 'honestli'): 1,
#           ('time', 'honestli', 'id'): 1,
#           ('honestli', 'id', 'surpris'): 1,
#           ('id', 'surpris', 'didn'): 1,
#           ('surpris', 'didn', 'futur'): 1,
#           ('didn', 'futur', 'project'): 1,
#           ('futur', 'project', 'he'): 1,
#           ('project', 'he', 'join'): 1,
#           ('he', 'join', 'friend'): 1,
#           ('join', 'friend', 'katyawkwafina'): 1,
#           ('friend', 'katyawkwafina', 'quickli'): 1,
#           ('katyawkwafina', 'quickli', 'provid'): 1,
#           ('quickli', 'provid', 'lot'): 1,
#           ('provid', 'lot', 'comic'): 1,
#           ('lot', 'comic', 'relief'): 1,
#           ('comic', 'relief', 'someth'): 1,
#           ('relief', 'someth', 'in'): 1,
#           ('someth', 'in', 'told'): 1,
#           ('in', 'told', 'she'): 1,
#           ('told', 'she', 'gener'): 1,
#           ('she', 'gener', 'adept'): 1,
#           ('gener', 'adept', 'best'): 1,
#           ('adept', 'best', 'describ'): 1,
#           ('best', 'describ', 'ten'): 1,
#           ('describ', 'ten', 'reunion'): 1,
#           ('ten', 'reunion', 'allow'): 1,
#           ('reunion', 'allow', 'movi'): 1,
#           ('allow', 'movi', 'realli'): 1,
#           ('movi', 'realli', 'mine'): 1,
#           ('realli', 'mine', 'famili'): 1,
#           ('mine', 'famili', 'melodrama'): 1,
#           ('famili', 'melodrama', 'one'): 1,
#           ('melodrama', 'one', 'best'): 1,
#           ('one', 'best', 'element'): 1,
#           ('best', 'element', 'wont'): 1,
#           ('element', 'wont', 'give'): 1,
#           ('wont', 'give', 'away'): 2,
#           ('give', 'away', 'exactli'): 1,
#           ('away', 'exactli', 'antagonist'): 1,
#           ('exactli', 'antagonist', 'intend'): 1,
#           ('antagonist', 'intend', 'hero'): 1,
#           ('intend', 'hero', 'stop'): 1,
#           ('hero', 'stop', 'howev'): 1,
#           ('stop', 'howev', 'figur'): 1,
#           ('howev', 'figur', 'mayb'): 1,
#           ('figur', 'mayb', 'even'): 1,
#           ('mayb', 'even', 'even'): 1,
#           ('even', 'even', 'possibl'): 1,
#           ('even', 'possibl', 'quit'): 1,
#           ('possibl', 'quit', 'yet'): 1,
#           ('quit', 'yet', 'almost'): 1,
#           ('yet', 'almost', 'black'): 1,
#           ('almost', 'black', 'anoth'): 1,
#           ('black', 'anoth', 'asia'): 2,
#           ('anoth', 'asia', 'audienc'): 1,
#           ('asia', 'audienc', 'lot'): 1,
#           ('audienc', 'lot', 'representationinclud'): 1,
#           ('lot', 'representationinclud', 'woman'): 1,
#           ('representationinclud', 'woman', 'best'): 1,
#           ('woman', 'best', 'charact'): 1,
#           ('best', 'charact', 'femal'): 1,
#           ('charact', 'femal', 'addit'): 1,
#           ('femal', 'addit', 'two'): 1,
#           ('addit', 'two', 'give'): 1,
#           ('two', 'give', 'alreadi'): 1,
#           ('give', 'alreadi', 'mention'): 1,
#           ('alreadi', 'mention', 'also'): 1,
#           ('mention', 'also', 'king'): 1,
#           ('also', 'king', 'nanyeoh'): 1,
#           ('king', 'nanyeoh', 'wise'): 1,
#           ('nanyeoh', 'wise', 'posit'): 1,
#           ('wise', 'posit', 'drench'): 1,
#           ('posit', 'drench', 'chine'): 1,
#           ('drench', 'chine', 'cultureth'): 1,
#           ('chine', 'cultureth', 'third'): 1,
#           ('cultureth', 'third', 'act'): 1,
#           ('third', 'act', 'way'): 1,
#           ('act', 'way', 'feel'): 1,
#           ('way', 'feel', 'like'): 1,
#           ('feel', 'like', 'belong'): 1,
#           ('like', 'belong', 'complet'): 1,
#           ('belong', 'complet', 'differ'): 1,
#           ('complet', 'differ', 'film'): 1,
#           ('differ', 'film', 'first'): 1,
#           ('film', 'first', 'two'): 1,
#           ('first', 'two', 'take'): 1,
#           ('two', 'take', 'especi'): 1,
#           ('take', 'especi', 'deep'): 1,
#           ('especi', 'deep', 'dive'): 1,
#           ('deep', 'dive', 'ultim'): 1,
#           ('dive', 'ultim', 'present'): 1,
#           ('ultim', 'present', 'western'): 1,
#           ('present', 'western', 'len'): 1,
#           ('western', 'len', 'clearli'): 1,
#           ('len', 'clearli', 'need'): 1,
#           ('clearli', 'need', 'go'): 1,
#           ('need', 'go', 'direct'): 1,
#           ('go', 'direct', 'still'): 1,
#           ('direct', 'still', 'big'): 1,
#           ('still', 'big', 'deal'): 1,
#           ('big', 'deal', 'put'): 1,
#           ('deal', 'put', 'much'): 1,
#           ('put', 'much', 'estim'): 1,
#           ('much', 'estim', '150'): 1,
#           ('estim', '150', '200'): 1,
#           ('150', '200', 'million'): 1,
#           ('200', 'million', 'major'): 1,
#           ('million', 'major', 'blockbust'): 1,
#           ('major', 'blockbust', 'seen'): 1,
#           ('blockbust', 'seen', 'million'): 1,
#           ('seen', 'million', 'peopl'): 1,
#           ('million', 'peopl', 'would'): 1,
#           ('peopl', 'would', 'never'): 1,
#           ('would', 'never', 'consid'): 1,
#           ('never', 'consid', 'watch'): 1,
#           ('consid', 'watch', 'art'): 1,
#           ('watch', 'art', 'pictur'): 1,
#           ('art', 'pictur', 'especi'): 1,
#           ('pictur', 'especi', 'one'): 1,
#           ('especi', 'one', 'rous'): 1,
#           ('one', 'rous', 'group'): 1,
#           ('rous', 'group', 'dont'): 1,
#           ('group', 'dont', 'belong'): 1,
#           ('dont', 'belong', 'point'): 1,
#           ('belong', 'point', 'countless'): 1,
#           ('point', 'countless', 'time'): 1,
#           ('countless', 'time', 'make'): 1,
#           ('time', 'make', 'sen'): 2,
#           ('make', 'sen', 'major'): 1,
#           ('sen', 'major', 'charact'): 1,
#           ('major', 'charact', 'speak'): 1,
#           ('charact', 'speak', 'makarin'): 1,
#           ('speak', 'makarin', 'rather'): 1,
#           ('makarin', 'rather', 'english'): 1,
#           ('rather', 'english', 'submit'): 1,
#           ('english', 'submit', 'dont'): 1,
#           ('submit', 'dont', 'worri'): 1,
#           ('dont', 'worri', 'think'): 1,
#           ('worri', 'think', 'follow'): 1,
#           ('think', 'follow', 'import'): 1,
#           ('follow', 'import', 'white'): 1,
#           ('import', 'white', 'peopl'): 1,
#           ('white', 'peopl', 'screen'): 1,
#           ('peopl', 'screen', 'agent'): 1,
#           ('screen', 'agent', 'made'): 1,
#           ('agent', 'made', 'le'): 1,
#           ('made', 'le', 'actioneach'): 1,
#           ('le', 'actioneach', 'sequenc'): 1,
#           ('actioneach', 'sequenc', 'feel'): 1,
#           ('sequenc', 'feel', 'distinct'): 1,
#           ('feel', 'distinct', 'belong'): 1,
#           ('distinct', 'belong', 'rest'): 1,
#           ('belong', 'rest', 'memor'): 1,
#           ('rest', 'memor', 'pay'): 1,
#           ('memor', 'pay', 'tribut'): 1,
#           ('pay', 'tribut', 'mani'): 1,
#           ('tribut', 'mani', 'differ'): 1,
#           ('mani', 'differ', 'kind'): 1,
#           ('differ', 'kind', 'martial'): 1,
#           ('kind', 'martial', 'art'): 1,
#           ('martial', 'art', 'film'): 11,
#           ('art', 'film', 'acknowledg'): 1,
#           ('film', 'acknowledg', 'stand'): 1,
#           ('acknowledg', 'stand', 'shoulder'): 1,
#           ('stand', 'shoulder', 'giant'): 1,
#           ('shoulder', 'giant', 'jacket'): 1,
#           ('giant', 'jacket', 'than'): 1,
#           ('jacket', 'than', 'julia'): 1,
#           ('than', 'julia', 'etc'): 1,
#           ('julia', 'etc', 'choreographi'): 1,
#           ('etc', 'choreographi', 'match'): 1,
#           ('choreographi', 'match', 'skill'): 1,
#           ('match', 'skill', 'cinematographi'): 1,
#           ('skill', 'cinematographi', 'see'): 1,
#           ('cinematographi', 'see', 'incred'): 1,
#           ('see', 'incred', 'fight'): 1,
#           ('incred', 'fight', 'camera'): 1,
#           ('fight', 'camera', 'dynam'): 1,
#           ('camera', 'dynam', 'celebr'): 1,
#           ('dynam', 'celebr', 'highlight'): 1,
#           ('celebr', 'highlight', 'incred'): 1,
#           ('highlight', 'incred', 'hire'): 1,
#           ('incred', 'hire', 'bill'): 1,
#           ('hire', 'bill', 'pope'): 1,
#           ('bill', 'pope', 'director'): 2,
#           ('pope', 'director', 'photographi'): 1,
#           ('director', 'photographi', 'matrix'): 1,
#           ('photographi', 'matrix', 'trilog'): 1,
#           ('matrix', 'trilog', 'two'): 1,
#           ('trilog', 'two', 'sam'): 1,
#           ('two', 'sam', 'aim'): 1,
#           ('sam', 'aim', 'spiderman'): 2,
#           ('aim', 'spiderman', 'entri'): 1,
#           ('spiderman', 'entri', 'parkman'): 1,
#           ('entri', 'parkman', 'team'): 1,
#           ('parkman', 'team', 'america'): 1,
#           ('team', 'america', 'special'): 1,
#           ('america', 'special', 'effect'): 1,
#           ('special', 'effect', 'excel'): 1,
#           ('effect', 'excel', 'issu'): 1,
#           ('excel', 'issu', 'pace'): 1,
#           ('issu', 'pace', 'certainli'): 1,
#           ('pace', 'certainli', 'chink'): 1,
#           ('certainli', 'chink', 'compos'): 1,
#           ('chink', 'compos', 'almost'): 1,
#           ('compos', 'almost', 'entir'): 1,
#           ('almost', 'entir', 'flashback'): 1,
#           ('entir', 'flashback', 'featur'): 1,
#           ('flashback', 'featur', 'rel'): 1,
#           ('featur', 'rel', 'brief'): 1,
#           ('rel', 'brief', 'highli'): 1,
#           ('brief', 'highli', 'concentr'): 1,
#           ('highli', 'concentr', 'surprisingli'): 1,
#           ('concentr', 'surprisingli', 'graphic'): 1,
#           ('surprisingli', 'graphic', 'gorey'): 1,
#           ('graphic', 'gorey', 'know'): 1,
#           ('gorey', 'know', 'time'): 1,
#           ('know', 'time', 'fact'): 1,
#           ('time', 'fact', 'happen'): 1,
#           ('fact', 'happen', 'be'): 1,
#           ('happen', 'be', 'clearli'): 1,
#           ('be', 'clearli', 'human'): 1,
#           ('clearli', 'human', 'want'): 1,
#           ('human', 'want', 'enough'): 1,
#           ('want', 'enough', 'get'): 1,
#           ('enough', 'get', 'away'): 1,
#           ('get', 'away', 'kind'): 1,
#           ('away', 'kind', 'thing'): 1,
#           ('kind', 'thing', 'pg'): 1,
#           ('thing', 'pg', 'rate'): 1,
#           ('pg', 'rate', 'pepperidg'): 1,
#           ('rate', 'pepperidg', 'farm'): 1,
#           ('pepperidg', 'farm', 'rememb'): 1,
#           ('farm', 'rememb', 'well'): 1,
#           ('rememb', 'well', 'littl'): 1,
#           ('well', 'littl', 'strong'): 1,
#           ('littl', 'strong', 'languag'): 1,
#           ('strong', 'languag', 'recommend'): 1,
#           ('languag', 'recommend', 'fan'): 1,
#           ('recommend', 'fan', 'comic'): 1,
#           ('fan', 'comic', 'book'): 1,
#           ('comic', 'book', 'movi'): 4,
#           ('book', 'movi', 'adapt'): 1,
#           ('movi', 'adapt', 'peopl'): 1,
#           ('adapt', 'peopl', 'passion'): 1,
#           ('peopl', 'passion', 'diver'): 1,
#           ('passion', 'diver', 'hire'): 1,
#           ('diver', 'hire', '810'): 1,
#           ('hire', '810', 'u'): 1,
#           ('810', 'u', 'govern'): 1,
#           ('u', 'govern', 'almost'): 1,
#           ('govern', 'almost', 'top'): 1,
#           ('almost', 'top', 'pretend'): 1,
#           ('top', 'pretend', 'name'): 1,
#           ('pretend', 'name', 'orang'): 1,
#           ('name', 'orang', 'went'): 1,
#           ('orang', 'went', 'toni'): 1,
#           ('went', 'toni', 'lung'): 5,
#           ('toni', 'lung', 'quot'): 1,
#           ('lung', 'quot', 'typic'): 1,
#           ('quot', 'typic', 'lightheart'): 1,
#           ('typic', 'lightheart', 'also'): 1,
#           ('lightheart', 'also', 'seriou'): 1,
#           ('also', 'seriou', 'addit'): 1,
#           ('seriou', 'addit', 'you'): 1,
#           ('addit', 'you', 'shangchi'): 1,
#           ('you', 'shangchi', 'legend'): 3,
#           ('shangchi', 'legend', 'ten'): 88,
#           ('legend', 'ten', 'ring'): 101,
#           ('ten', 'ring', 'although'): 1,
#           ('ring', 'although', 'marvel'): 1,
#           ('although', 'marvel', 'alway'): 1,
#           ('marvel', 'alway', 'le'): 1,
#           ('alway', 'le', 'seriou'): 1,
#           ('le', 'seriou', 'do'): 1,
#           ('seriou', 'do', 'time'): 1,
#           ('do', 'time', 'leav'): 1,
#           ('time', 'leav', 'sherman'): 1,
#           ('leav', 'sherman', 'batman'): 1,
#           ('sherman', 'batman', 'cri'): 1,
#           ('batman', 'cri', 'case'): 1,
#           ('cri', 'case', 'sweet'): 1,
#           ('case', 'sweet', 'superhero'): 1,
#           ('sweet', 'superhero', 'seanshangchi'): 1,
#           ('superhero', 'seanshangchi', 'situ'): 1,
#           ('seanshangchi', 'situ', 'lie'): 1,
#           ('situ', 'lie', 'human'): 1,
#           ('lie', 'human', 'almost'): 1,
#           ('human', 'almost', 'hero'): 1,
#           ('almost', 'hero', 'use'): 1,
#           ('hero', 'use', 'martial'): 1,
#           ('use', 'martial', 'art'): 2,
#           ('martial', 'art', 'press'): 1,
#           ('art', 'press', 'open'): 1,
#           ('press', 'open', 'sequenc'): 1,
#           ('open', 'sequenc', 'bu'): 1,
#           ('sequenc', 'bu', 'see'): 1,
#           ('bu', 'see', 'bad'): 1,
#           ('see', 'bad', 'come'): 1,
#           ('bad', 'come', 'cinemat'): 1,
#           ('come', 'cinemat', 'bu'): 1,
#           ('cinemat', 'bu', 'ride'): 1,
#           ('bu', 'ride', 'nobodi'): 1,
#           ('ride', 'nobodi', 'rous'): 1,
#           ('nobodi', 'rous', 'entertain'): 1,
#           ('rous', 'entertain', 'fight'): 1,
#           ('entertain', 'fight', 'sequenc'): 1,
#           ('fight', 'sequenc', 'laugh'): 1,
#           ('sequenc', 'laugh', 'balletlik'): 1,
#           ('laugh', 'balletlik', 'composit'): 1,
#           ('balletlik', 'composit', 'satisfi'): 1,
#           ('composit', 'satisfi', 'set'): 1,
#           ('satisfi', 'set', 'charact'): 1,
#           ('set', 'charact', 'motiv'): 1,
#           ('charact', 'motiv', 'thing'): 1,
#           ('motiv', 'thing', 'get'): 1,
#           ('thing', 'get', 'heavi'): 1,
#           ('get', 'heavi', 'seen'): 1,
#           ('heavi', 'seen', 'must'): 1,
#           ('seen', 'must', 'confront'): 1,
#           ('must', 'confront', 'potenti'): 1,
#           ('confront', 'potenti', 'kill'): 1,
#           ('potenti', 'kill', '1000yearold'): 1,
#           ('kill', '1000yearold', 'monster'): 1,
#           ('1000yearold', 'monster', 'dad'): 1,
#           ('monster', 'dad', 'went'): 1,
#           ('dad', 'went', 'awkwafina'): 1,
#           ('went', 'awkwafina', 'kate'): 1,
#           ('awkwafina', 'kate', 'mean'): 1,
#           ('kate', 'mean', 'girlfriend'): 1,
#           ('mean', 'girlfriend', 'amus'): 1,
#           ('girlfriend', 'amus', 'loneli'): 1,
#           ('amus', 'loneli', 'throughout'): 1,
#           ('loneli', 'throughout', 'adventur'): 1,
#           ('throughout', 'adventur', 'right'): 1,
#           ('adventur', 'right', 'lifesav'): 1,
#           ('right', 'lifesav', 'shot'): 1,
#           ('lifesav', 'shot', 'big'): 1,
#           ('shot', 'big', 'end'): 1,
#           ('big', 'end', 'battl'): 1,
#           ('end', 'battl', 'scene'): 1,
#           ('battl', 'scene', 'director'): 1,
#           ('scene', 'director', 'destini'): 1,
#           ('director', 'destini', 'daniel'): 14,
#           ('destini', 'daniel', 'cotton'): 39,
#           ('daniel', 'cotton', 'deftli'): 1,
#           ('cotton', 'deftli', 'orchestr'): 1,
#           ('deftli', 'orchestr', 'fight'): 1,
#           ('orchestr', 'fight', 'charact'): 1,
#           ('fight', 'charact', 'line'): 1,
#           ('charact', 'line', 'author'): 1,
#           ('line', 'author', 'much'): 1,
#           ('author', 'much', 'season'): 1,
#           ('much', 'season', 'filmmak'): 1,
#           ('season', 'filmmak', 'never'): 1,
#           ('filmmak', 'never', 'lose'): 1,
#           ('never', 'lose', 'sight'): 1,
#           ('lose', 'sight', 'central'): 1,
#           ('sight', 'central', 'motifth'): 1,
#           ('central', 'motifth', 'affirm'): 1,
#           ('motifth', 'affirm', 'famili'): 1,
#           ('affirm', 'famili', 'primaci'): 1,
#           ('famili', 'primaci', 'potenti'): 1,
#           ('primaci', 'potenti', 'chao'): 1,
#           ('potenti', 'chao', 'giant'): 1,
#           ('chao', 'giant', 'cast'): 1,
#           ('giant', 'cast', 'multipl'): 1,
#           ('cast', 'multipl', 'plot'): 1,
#           ('multipl', 'plot', 'strand'): 1,
#           ('plot', 'strand', 'host'): 1,
#           ('strand', 'host', 'uniti'): 1,
#           ('host', 'uniti', 'glu'): 1,
#           ('uniti', 'glu', 'charact'): 1,
#           ('glu', 'charact', 'dialogu'): 1,
#           ('charact', 'dialogu', 'shangchi'): 1,
#           ('dialogu', 'shangchi', 'marvel'): 1,
#           ('shangchi', 'marvel', 'whole'): 1,
#           ('marvel', 'whole', 'famili'): 1,
#           ('whole', 'famili', 'especi'): 1,
#           ('famili', 'especi', 'cinephil'): 1,
#           ('especi', 'cinephil', 'curiou'): 1,
#           ('cinephil', 'curiou', 'marvel'): 1,
#           ('curiou', 'marvel', 'cinemat'): 1,
#           ('marvel', 'cinemat', 'univers'): 42,
#           ('cinemat', 'univers', 'diver'): 1,
#           ('univers', 'diver', 'entertain'): 1,
#           ('diver', 'entertain', 'perfect'): 1,
#           ('entertain', 'perfect', 'purveyor'): 1,
#           ('perfect', 'purveyor', 'heroic'): 1,
#           ('purveyor', 'heroic', 'fantasi'): 1,
#           ('heroic', 'fantasi', 'watch'): 1,
#           ('fantasi', 'watch', 'max'): 1,
#           ('watch', 'max', 'entir'): 1,
#           ('max', 'entir', 'movi'): 1,
#           ('entir', 'movi', 'expand'): 1,
#           ('movi', 'expand', 'aspect'): 1,
#           ('expand', 'aspect', 'ratio'): 1,
#           ('aspect', 'ratio', 'your'): 1,
#           ('ratio', 'your', 'watch'): 1,
#           ('your', 'watch', '70'): 1,
#           ('watch', '70', 'imag'): 1,
#           ('70', 'imag', 'normal'): 1,
#           ('imag', 'normal', 'screen'): 1,
#           ('normal', 'screen', 'plu'): 1,
#           ('screen', 'plu', 'way'): 1,
#           ('plu', 'way', 'smaller'): 1,
#           ('way', 'smaller', 'screen'): 1,
#           ('smaller', 'screen', 'wors'): 1,
#           ('screen', 'wors', 'speaker'): 1,
#           ('wors', 'speaker', 'promis'): 1,
#           ('speaker', 'promis', 'worth'): 1,
#           ('promis', 'worth', 'wowowowowow'): 1,
#           ('worth', 'wowowowowow', 'movi'): 1,
#           ('wowowowowow', 'movi', 'blew'): 1,
#           ('movi', 'blew', 'away'): 2,
#           ('blew', 'away', 'love'): 1,
#           ('away', 'love', 'lot'): 1,
#           ('love', 'lot', 'begin'): 1,
#           ('lot', 'begin', 'end'): 1,
#           ('begin', 'end', 'everyth'): 1,
#           ('end', 'everyth', 'walk'): 1,
#           ('everyth', 'walk', 'movi'): 1,
#           ('walk', 'movi', 'hope'): 1,
#           ('movi', 'hope', 'silentscream'): 1,
#           ('hope', 'silentscream', 'mask'): 1,
#           ('silentscream', 'mask', 'walk'): 1,
#           ('mask', 'walk', 'car'): 1,
#           ('walk', 'car', 'sinc'): 1,
#           ('car', 'sinc', 'walk'): 1,
#           ('sinc', 'walk', 'movi'): 1,
#           ('walk', 'movi', 'happi'): 1,
#           ('movi', 'happi', 'much'): 1,
#           ('happi', 'much', 'say'): 1,
#           ('much', 'say', 'love'): 1,
#           ('say', 'love', 'you'): 1,
#           ('love', 'you', 'lot'): 1,
#           ('you', 'lot', 'thing'): 1,
#           ('lot', 'thing', 'frequent'): 1,
#           ('thing', 'frequent', 'lack'): 1,
#           ('frequent', 'lack', 'one'): 1,
#           ('lack', 'one', 'good'): 1,
#           ('one', 'good', 'fight'): 1,
#           ('good', 'fight', 'scene'): 5,
#           ('fight', 'scene', 'alway'): 2,
#           ('scene', 'alway', 'awesom'): 2,
#           ('alway', 'awesom', 'action'): 1,
#           ('awesom', 'action', 'scene'): 3,
#           ('action', 'scene', 'specif'): 1,
#           ('scene', 'specif', 'fight'): 1,
#           ('specif', 'fight', 'scene'): 2,
#           ('fight', 'scene', 'usual'): 2,
#           ('scene', 'usual', 'pretti'): 1,
#           ('usual', 'pretti', 'good'): 1,
#           ('pretti', 'good', 'great'): 1,
#           ('good', 'great', 'move'): 1,
#           ('great', 'move', 'like'): 1,
#           ('move', 'like', 'civil'): 1,
#           ('like', 'civil', 'war'): 1,
#           ('civil', 'war', 'winter'): 1,
#           ('war', 'winter', 'soldier'): 1,
#           ('winter', 'soldier', 'gener'): 1,
#           ('soldier', 'gener', 'fight'): 1,
#           ('gener', 'fight', 'scene'): 1,
#           ('fight', 'scene', 'american'): 1,
#           ('scene', 'american', 'move'): 1,
#           ('american', 'move', 'pale'): 1,
#           ('move', 'pale', 'comparison'): 1,
#           ('pale', 'comparison', 'asia'): 1,
#           ('comparison', 'asia', 'cinema'): 1,
#           ('asia', 'cinema', 'in'): 1,
#           ('cinema', 'in', 'man'): 1,
#           ('in', 'man', 'raid'): 1,
#           ('man', 'raid', 'redempt'): 1,
#           ('raid', 'redempt', 'anyth'): 1,
#           ('redempt', 'anyth', 'jacket'): 1,
#           ('anyth', 'jacket', 'than'): 2,
#           ('jacket', 'than', 'fight'): 3,
#           ('than', 'fight', 'scene'): 1,
#           ('fight', 'scene', 'movi'): 6,
#           ('scene', 'movi', 'describ'): 1,
#           ('movi', 'describ', 'amaz'): 1,
#           ('describ', 'amaz', 'martial'): 1,
#           ('amaz', 'martial', 'art'): 5,
#           ('martial', 'art', 'that'): 1,
#           ('art', 'that', 'fast'): 1,
#           ('that', 'fast', 'clear'): 1,
#           ('fast', 'clear', 'fill'): 1,
#           ('clear', 'fill', 'creativ'): 1,
#           ('fill', 'creativ', 'astonish'): 1,
#           ('creativ', 'astonish', 'way'): 1,
#           ('astonish', 'way', 'without'): 1,
#           ('way', 'without', 'hint'): 1,
#           ('without', 'hint', 'shake'): 1,
#           ('hint', 'shake', 'can'): 1,
#           ('shake', 'can', 'quick'): 1,
#           ('can', 'quick', 'cut'): 1,
#           ('quick', 'cut', 'cunningli'): 1,
#           ('cut', 'cunningli', 'beauti'): 1,
#           ('cunningli', 'beauti', 'backdrop'): 1,
#           ('beauti', 'backdrop', 'phenomenon'): 1,
#           ('backdrop', 'phenomenon', 'continu'): 1,
#           ('phenomenon', 'continu', 'focu'): 1,
#           ('continu', 'focu', 'fight'): 1,
#           ('focu', 'fight', 'instead'): 1,
#           ('fight', 'instead', 'cut'): 1,
#           ('instead', 'cut', 'differ'): 1,
#           ('cut', 'differ', 'scene'): 1,
#           ('differ', 'scene', '10'): 1,
#           ('scene', '10', 'second'): 1,
#           ('10', 'second', 'like'): 2,
#           ('second', 'like', 'give'): 1,
#           ('like', 'give', 'notic'): 1,
#           ('give', 'notic', 'you'): 1,
#           ('notic', 'you', 'far'): 1,
#           ('you', 'far', 'best'): 2,
#           ('far', 'best', 'fight'): 1,
#           ('best', 'fight', 'you'): 2,
#           ('fight', 'you', 'even'): 1,
#           ('you', 'even', 'close'): 1,
#           ('even', 'close', 'john'): 1,
#           ('close', 'john', 'wick'): 1,
#           ('john', 'wick', 'seri'): 1,
#           ('wick', 'seri', 'netflix'): 1,
#           ('seri', 'netflix', 'daredevil'): 1,
#           ('netflix', 'daredevil', 'best'): 1,
#           ('daredevil', 'best', 'were'): 1,
#           ('best', 'were', 'seen'): 1,
#           ('were', 'seen', 'america'): 1,
#           ('seen', 'america', 'late'): 1,
#           ('america', 'late', 'love'): 1,
#           ('late', 'love', 'first'): 1,
#           ('love', 'first', 'major'): 1,
#           ('first', 'major', 'fight'): 1,
#           ('major', 'fight', 'scene'): 1,
#           ('fight', 'scene', 'much'): 2,
#           ('scene', 'much', 'worri'): 1,
#           ('much', 'worri', 'would'): 1,
#           ('worri', 'would', 'best'): 1,
#           ('would', 'best', 'one'): 1,
#           ('best', 'one', 'movi'): 2,
#           ('one', 'movi', 'far'): 1,
#           ('movi', 'far', 'earli'): 1,
#           ('far', 'earli', 'll'): 1,
#           ('earli', 'll', 'stupid'): 1,
#           ('ll', 'stupid', 'sometim'): 2,
#           ('stupid', 'sometim', 'anoth'): 1,
#           ('sometim', 'anoth', 'frequent'): 1,
#           ('anoth', 'frequent', 'flaw'): 1,
#           ('frequent', 'flaw', 'you'): 1,
#           ('flaw', 'you', 'lack'): 1,
#           ('you', 'lack', 'compel'): 1,
#           ('lack', 'compel', 'villain'): 1,
#           ('compel', 'villain', 'hope'): 1,
#           ('villain', 'hope', 'awesom'): 1,
#           ('hope', 'awesom', 'awesom'): 1,
#           ('awesom', 'awesom', 'awesom'): 1,
#           ('awesom', 'awesom', 'that'): 1,
#           ('awesom', 'that', 'ill'): 1,
#           ('that', 'ill', 'say'): 1,
#           ('ill', 'say', 'anoth'): 1,
#           ('say', 'anoth', 'frequent'): 1,
#           ('anoth', 'frequent', 'complaint'): 1,
#           ('frequent', 'complaint', 'music'): 1,
#           ('complaint', 'music', 'score'): 1,
#           ('music', 'score', 'except'): 1,
#           ('score', 'except', 'dont'): 1,
#           ('except', 'dont', 'stand'): 1,
#           ('dont', 'stand', 'think'): 1,
#           ('stand', 'think', 'heard'): 1,
#           ('think', 'heard', 'there'): 1,
#           ('heard', 'there', 'good'): 1,
#           ('there', 'good', 'streak'): 1,
#           ('good', 'streak', 'show'): 1,
#           ('streak', 'show', 'black'): 1,
#           ('show', 'black', 'widow'): 1,
#           ('black', 'widow', 'amaz'): 1,
#           ('widow', 'amaz', 'loi'): 1,
#           ('amaz', 'loi', 'score'): 1,
#           ('loi', 'score', 'like'): 1,
#           ('score', 'like', 'felt'): 1,
#           ('like', 'felt', 'uniqu'): 1,
#           ...})

# %% [markdown]
# **Probability of bi-grams**

# %%
from collections import Counter
bi_grams = nltk.bigrams(iterations)
frequency_dist = nltk.FreqDist(bi_grams)
bi_grams_dict = dict(frequency_dist)
for word in bi_grams_dict:
  print( str(word) + ':' + str(bi_grams_dict[word] / iterations.count(word[0])))
# Out:
# Streaming output truncated to the last 5000 lines.
# ('dragon', 'marvel'):0.015873015873015872
# ('action', 'drama'):0.0019120458891013384
# ('movi', 'el'):0.0006807351940095302
# ('el', 'expect'):0.05555555555555555
# ('we', 'overshadow'):0.1111111111111111
# ('overshadow', 'situ'):0.1111111111111111
# ('lie', 'sang'):0.006060606060606061
# ('chi', 'lung'):0.003125
# ('actor', 'knew'):0.009345794392523364
# ('knew', 'sinc'):0.045454545454545456
# ('sinc', 'infern'):0.0136986301369863
# ('affair', 'brought'):0.25
# ('charact', 'wen'):0.0015625
# ('we', 'best'):0.1111111111111111
# ('one', 'el'):0.002150537634408602
# ('could', 'even'):0.017391304347826087
# ('even', 'stood'):0.004878048780487805
# ('stood', 'without'):0.2
# ('without', 'dialogu'):0.015625
# ('feel', 'charisma'):0.004524886877828055
# ('charisma', 'id'):0.1
# ('id', 'go'):0.03125
# ('see', 'watch'):0.0028653295128939827
# ('watch', 'wen'):0.002638522427440633
# ('we', 'situ'):0.1111111111111111
# ('lie', 'long'):0.006060606060606061
# ('way', 'ahead'):0.005813953488372093
# ('ahead', 'better'):0.14285714285714285
# ('better', 'actor'):0.006134969325153374
# ('one', 'ok'):0.002150537634408602
# ('ok', 'go'):0.034482758620689655
# ('see', 'famili'):0.0028653295128939827
# ('famili', 'fun'):0.010869565217391304
# ('you', 'better'):0.0041753653444676405
# ('better', 'engag'):0.006134969325153374
# ('engag', 'forg'):0.016666666666666666
# ('forg', 'e'):0.3333333333333333
# ('e', 'mierda'):0.3333333333333333
# ('mierda', 'movi'):0.5
# ('movi', 'suck'):0.0013614703880190605
# ('suck', 'like'):0.09090909090909091
# ('like', 'forg'):0.001851851851851852
# ('forg', 'la'):0.3333333333333333
# ('la', 'mierda'):0.14285714285714285
# ('mierda', 'better'):0.5
# ('better', 'iron'):0.012269938650306749
# ('3', 'enjoy'):0.023255813953488372
# ('scene', 'must'):0.0019011406844106464
# ('like', 'head'):0.001851851851851852
# ('head', 'chine'):0.0625
# ('chine', 'black'):0.006666666666666667
# ('anoth', 'truth'):0.005681818181818182
# ('truth', 'film'):0.08333333333333333
# ('anoth', 'want'):0.005681818181818182
# ('want', 'grow'):0.005988023952095809
# ('grow', 'easili'):0.05555555555555555
# ('probabl', 'compet'):0.02
# ('compet', 'guardian'):0.2
# ('galaxi', 'favorit'):0.125
# ('favorit', 'bunch'):0.03125
# ('bunch', 'sever'):0.09090909090909091
# ('sever', 'nod'):0.045454545454545456
# ('nod', 'wider'):0.125
# ('univers', 'your'):0.008130081300813009
# ('your', 'richard'):0.02631578947368421
# ('richard', 'fan'):0.3333333333333333
# ('fan', 'they'):0.00684931506849315
# ('they', 'quit'):0.09090909090909091
# ('quit', 'reward'):0.012345679012345678
# ('reward', 'never'):0.5
# ('never', 'distract'):0.0136986301369863
# ('distract', 'mostli'):0.16666666666666666
# ('mostli', 'selfcontain'):0.043478260869565216
# ('selfcontain', 'stori'):1.0
# ('time', 'serious'):0.0036496350364963502
# ('serious', 'laughoutloud'):0.05555555555555555
# ('laughoutloud', 'funni'):0.5
# ('funni', 'never'):0.00980392156862745
# ('never', 'fall'):0.0136986301369863
# ('trap', 'allow'):0.25
# ('allow', 'humor'):0.08333333333333333
# ('humor', 'undermin'):0.014492753623188406
# ('undermin', 'emot'):1.0
# ('moment', 'ben'):0.010101010101010102
# ('dingley', 'awkwafina'):0.06666666666666667
# ('awkwafina', 'give'):0.006711409395973154
# ('give', 'particularli'):0.0049504950495049506
# ('particularli', 'standout'):0.05
# ('standout', 'perform'):0.125
# ('perform', 'matter'):0.010752688172043012
# ('matter', 'shall'):0.06666666666666667
# ('shall', 'say'):1.0
# ('say', 'overt'):0.005988023952095809
# ('overt', 'comedi'):1.0
# ('comedi', 'style'):0.008771929824561403
# ('style', 'get'):0.01639344262295082
# ('get', 'grate'):0.0049504950495049506
# ('grate', 'know'):0.125
# ('know', 'deliv'):0.007751937984496124
# ('deliv', 'small'):0.018867924528301886
# ('small', 'dose'):0.08333333333333333
# ('dose', 'also'):0.25
# ('also', 'surprisingli'):0.0035335689045936395
# ('surprisingli', 'heartfelt'):0.08333333333333333
# ('heartfelt', 'moment'):0.25
# ('moment', 'perhap'):0.010101010101010102
# ('perhap', 'spectacular'):0.058823529411764705
# ('spectacular', 'featur'):0.027777777777777776
# ('featur', 'movi'):0.043478260869565216
# ('movi', 'stuntwork'):0.0006807351940095302
# ('stuntwork', 'multipl'):0.5
# ('multipl', 'incred'):0.1111111111111111
# ('incred', 'long'):0.014925373134328358
# ('long', 'exceedingli'):0.007462686567164179
# ('exceedingli', 'wellchoreogrph'):1.0
# ('wellchoreogrph', 'fight'):1.0
# ('scene', 'creativ'):0.0019011406844106464
# ('creativ', 'crazi'):0.058823529411764705
# ('crazi', 'aromat'):0.045454545454545456
# ('aromat', 'fight'):0.5
# ('fight', 'sinc'):0.002105263157894737
# ('sinc', 'jacket'):0.0136986301369863
# ('chain', 'glori'):0.3333333333333333
# ('glori', 'day'):0.5
# ('day', 'long'):0.025
# ('cinema', 'other'):0.0125
# ('other', 'take'):0.034482758620689655
# ('take', 'clear'):0.010638297872340425
# ('clear', 'inspir'):0.041666666666666664
# ('inspir', 'dancelik'):0.03571428571428571
# ('dancelik', 'firework'):0.5
# ('firework', 'julia'):1.0
# ('dragon', 'even'):0.015873015873015872
# ('even', 'borrow'):0.004878048780487805
# ('borrow', 'one'):0.5
# ('one', 'lead'):0.002150537634408602
# ('one', 'throughout'):0.002150537634408602
# ('throughout', 'camerawork'):0.02702702702702703
# ('camerawork', 'clear'):0.25
# ('clear', 'without'):0.041666666666666664
# ('without', 'rapidfir'):0.015625
# ('rapidfir', 'cut'):1.0
# ('cut', 'pervad'):0.034482758620689655
# ('pervad', 'much'):1.0
# ('much', 'hollywood'):0.003676470588235294
# ('hollywood', 'cinematographi'):0.038461538461538464
# ('cinematographi', 'time'):0.013513513513513514
# ('take', 'wide'):0.010638297872340425
# ('wide', 'angl'):0.1111111111111111
# ('angl', 'realli'):0.25
# ('realli', 'showcas'):0.002793296089385475
# ('showcas', 'rather'):0.25
# ('rather', 'mask'):0.029411764705882353
# ('mask', 'stung'):0.3333333333333333
# ('stung', 'perform'):0.06666666666666667
# ('perform', 'time'):0.010752688172043012
# ('time', 'cameraman'):0.0036496350364963502
# ('cameraman', 'treat'):1.0
# ('treat', 'anoth'):0.03125
# ('anoth', 'perform'):0.005681818181818182
# ('perform', 'right'):0.010752688172043012
# ('right', 'heart'):0.015151515151515152
# ('heart', 'aromat'):0.023255813953488372
# ('aromat', 'choreographi'):0.5
# ('choreographi', 'practic'):0.007874015748031496
# ('practic', 'sound'):0.125
# ('sound', 'get'):0.030303030303030304
# ('get', 'lot'):0.009900990099009901
# ('attent', 'visual'):0.07142857142857142
# ('beauti', 'take'):0.006329113924050633
# ('take', 'full'):0.010638297872340425
# ('full', 'advantag'):0.021739130434782608
# ('advantag', 'blockbust'):0.25
# ('blockbust', 'budget'):0.041666666666666664
# ('budget', 'element'):0.09090909090909091
# ('element', 'effect'):0.018867924528301886
# ('effect', 'prove'):0.006711409395973154
# ('prove', 'liveact'):0.058823529411764705
# ('liveact', 'altar'):0.2
# ('could', 'work'):0.008695652173913044
# ('work', 'creatur'):0.008928571428571428
# ('creatur', 'rang'):0.023809523809523808
# ('rang', 'cut'):0.2
# ('cut', 'coldli'):0.034482758620689655
# ('coldli', 'anim'):1.0
# ('anim', 'monster'):0.045454545454545456
# ('monster', 'would'):0.09090909090909091
# ('make', 'kaiju'):0.00390625
# ('kaiju', 'film'):0.5
# ('film', 'jealou'):0.001059322033898305
# ('jealou', 'movi'):0.5
# ('pull', 'difficult'):0.07142857142857142
# ('difficult', 'trick'):0.1111111111111111
# ('trick', 'make'):0.3333333333333333
# ('make', 'energybas'):0.00390625
# ('energybas', 'swift'):1.0
# ('swift', 'weapon'):0.16666666666666666
# ('weapon', 'seem'):0.1111111111111111
# ('seem', 'raw'):0.012195121951219513
# ('raw', 'viscer'):0.14285714285714285
# ('viscer', 'center'):0.5
# ('center', 'spectacl'):0.3333333333333333
# ('spectacl', 'surprisingli'):0.07142857142857142
# ('surprisingli', 'reson'):0.08333333333333333
# ('reson', 'person'):0.5
# ('stori', 'broken'):0.0019157088122605363
# ('famili', 'toni'):0.010869565217391304
# ('incred', 'perform'):0.014925373134328358
# ('make', 'milleniaold'):0.00390625
# ('milleniaold', 'superpow'):1.0
# ('superpow', 'parlor'):0.25
# ('parlor', 'sympathet'):1.0
# ('sympathet', 'even'):0.14285714285714285
# ('even', 'reliabl'):0.004878048780487805
# ('reliabl', 'tubular'):0.07142857142857142
# ('embodi', 'one'):0.16666666666666666
# ('film', 'central'):0.001059322033898305
# ('theme', 'bring'):0.038461538461538464
# ('togeth', 'aspect'):0.022222222222222223
# ('aspect', 'disparag'):0.034482758620689655
# ('disparag', 'influenc'):0.3333333333333333
# ('influenc', 'forg'):0.125
# ('forg', 'uniqu'):0.3333333333333333
# ('uniqu', 'ident'):0.020833333333333332
# ('ident', 'lead'):0.14285714285714285
# ('lead', 'similar'):0.018518518518518517
# ('similar', 'stori'):0.045454545454545456
# ('stori', 'arguabl'):0.0019157088122605363
# ('arguabl', 'even'):0.25
# ('even', 'compel'):0.004878048780487805
# ('compel', 'shangchi'):0.045454545454545456
# ('right', 'bring'):0.015151515151515152
# ('bring', 'fresh'):0.01694915254237288
# ('take', 'you'):0.010638297872340425
# ('you', 'hollywood'):0.0020876826722338203
# ('filmmak', 'gener'):0.07692307692307693
# ('realli', 'knock'):0.002793296089385475
# ('one', 'definit'):0.002150537634408602
# ('ticket', 'great'):0.3333333333333333
# ('fight', 'plot'):0.002105263157894737
# ('plot', 'despit'):0.007751937984496124
# ('despit', 'maintain'):0.038461538461538464
# ('maintain', 'marvel'):0.2
# ('marvel', 'signatur'):0.0010141987829614604
# ('signatur', 'sometim'):0.5
# ('sometim', 'tediou'):0.03225806451612903
# ('tediou', 'rope'):0.3333333333333333
# ('rope', 'sang'):0.09090909090909091
# ('chi', 'shine'):0.003125
# ('shine', 'one'):0.041666666666666664
# ('time', 'action'):0.0036496350364963502
# ('action', 'simpli'):0.0019120458891013384
# ('simpli', 'put'):0.043478260869565216
# ('put', 'epic'):0.020833333333333332
# ('truli', 'awesom'):0.021739130434782608
# ('awesom', 'moment'):0.010526315789473684
# ('fantast', 'debut'):0.011363636363636364
# ('debut', 'charact'):0.1
# ('chi', 'grab'):0.003125
# ('grab', 'best'):0.2
# ('part', 'chine'):0.009259259259259259
# ('art', 'cinema'):0.005319148936170213
# ('cinema', 'marvelis'):0.0125
# ('marvelis', 'make'):1.0
# ('work', 'go'):0.017857142857142856
# ('honestli', 'expect'):0.027777777777777776
# ('expect', 'dislik'):0.006097560975609756
# ('dislik', 'given'):0.16666666666666666
# ('given', 'predict'):0.03571428571428571
# ('predict', 'marvel'):0.016129032258064516
# ('film', 'gotten'):0.001059322033898305
# ('gotten', 'gener'):0.14285714285714285
# ('gener', 'suffer'):0.02631578947368421
# ('suffer', 'marvel'):0.125
# ('marvel', 'boat'):0.0010141987829614604
# ('boat', 'sang'):1.0
# ('chi', 'surpass'):0.003125
# ('gave', 'two'):0.034482758620689655
# ('hour', 'awesom'):0.03333333333333333
# ('awesom', 'side'):0.010526315789473684
# ('side', 'note'):0.03333333333333333
# ('note', 'thing'):0.06666666666666667
# ('would', 'made'):0.005952380952380952
# ('le', 'marvel'):0.021739130434782608
# ('marvel', 'quit'):0.0010141987829614604
# ('quit', 'chees'):0.012345679012345678
# ('chees', 'like'):0.08333333333333333
# ('univers', 'overal'):0.008130081300813009
# ('movi', 'posit'):0.0006807351940095302
# ('posit', 'great'):0.1111111111111111
# ('lung', 'especi'):0.012269938650306749
# ('especi', 'toni'):0.031914893617021274
# ('lung', 'look'):0.012269938650306749
# ('look', 'adam'):0.016129032258064516
# ('adam', 'great'):0.14285714285714285
# ('skill', 'you'):0.1
# ('alreadi', 'heard'):0.058823529411764705
# ('heard', 'peopl'):0.16666666666666666
# ('peopl', 'prais'):0.018518518518518517
# ('prais', 'film'):0.08333333333333333
# ('choreographi', 'welldeserv'):0.015748031496062992
# ('welldeserv', 'doesn'):1.0
# ('doesn', 'mani'):0.02247191011235955
# ('mani', 'cut'):0.014184397163120567
# ('cut', 'scene'):0.06896551724137931
# ('felt', 'complet'):0.013605442176870748
# ('complet', 'uniqu'):0.04
# ('uniqu', 'were'):0.041666666666666664
# ('alreadi', 'drop'):0.058823529411764705
# ('drop', 'beauti'):0.16666666666666666
# ('cinematographi', 'soundtrack'):0.02702702702702703
# ('soundtrack', 'well'):0.06666666666666667
# ('great', 'first'):0.003913894324853229
# ('act', 'incred'):0.00904977375565611
# ('show', 'life'):0.018867924528301886
# ('life', 'shangchi'):0.0392156862745098
# ('went', 'meet'):0.017543859649122806
# ('meet', 'wife'):0.2
# ('wife', 'etc'):0.125
# ('etc', 'type'):0.09090909090909091
# ('type', 'act'):0.05555555555555555
# ('act', 'someth'):0.00904977375565611
# ('someth', 'you'):0.0196078431372549
# ('you', 'usual'):0.0041753653444676405
# ('doesn', 'film'):0.02247191011235955
# ('open', 'you'):0.05405405405405406
# ('you', 'new'):0.006263048016701462
# ('world', 'myth'):0.022222222222222223
# ('myth', 'creatur'):0.5
# ('creatur', 'mani'):0.047619047619047616
# ('mani', 'evil'):0.014184397163120567
# ('evil', 'organ'):0.125
# ('organ', 'mysteri'):0.08
# ('ring', 'neg'):0.008888888888888889
# ('neg', 'cast'):0.18181818181818182
# ('cast', 'cellar'):0.012903225806451613
# ('cellar', 'asid'):0.2857142857142857
# ('asid', 'one'):0.125
# ('person', 'didn'):0.05555555555555555
# ('care', 'razor'):0.06896551724137931
# ('fist', 'cough'):0.13333333333333333
# ('cough', 'everybodi'):0.25
# ('everybodi', 'play'):0.2222222222222222
# ('role', 'perfect'):0.023809523809523808
# ('joke', 'may'):0.027777777777777776
# ('may', 'funni'):0.037037037037037035
# ('funni', 'peopl'):0.0196078431372549
# ('peopl', 'funni'):0.018518518518518517
# ('funni', 'issu'):0.0196078431372549
# ('issu', 'shangchi'):0.047619047619047616
# ('bad', 'felt'):0.016
# ('felt', 'retract'):0.013605442176870748
# ('retract', 'first'):1.0
# ('word', 'movi'):0.14285714285714285
# ('movi', 'establish'):0.0013614703880190605
# ('establish', 'becom'):0.16666666666666666
# ('becom', 'everi'):0.031746031746031744
# ('you', 'logic'):0.0041753653444676405
# ('logic', 'partcgi'):0.5
# ('partcgi', 'battl'):1.0
# ('battl', 'took'):0.03225806451612903
# ('great', 'handtohand'):0.003913894324853229
# ('handtohand', 'action'):0.2222222222222222
# ('work', 'expect'):0.017857142857142856
# ('film', 'gene'):0.00211864406779661
# ('gene', 'charact'):0.09523809523809523
# ('charact', 'univers'):0.003125
# ('univers', 'mio'):0.016260162601626018
# ('mio', 'great'):0.2857142857142857
# ('way', 'introduc'):0.011627906976744186
# ('forward', 'shangchi'):0.08695652173913043
# ('also', 'went'):0.007067137809187279
# ('tier', 'film'):0.3076923076923077
# ('industri', 'top'):0.3333333333333333
# ('you', 'standalon'):0.0041753653444676405
# ('standalon', 'move'):0.14285714285714285
# ('move', 'decent'):0.0024390243902439024
# ('happi', 'comedi'):0.02702702702702703
# ('isn', 'everyon'):0.019230769230769232
# ('everyon', 'play'):0.023809523809523808
# ('play', 'littl'):0.01098901098901099
# ('littl', 'seriou'):0.009708737864077669
# ('seriou', 'makarin'):0.05555555555555555
# ('art', 'point'):0.005319148936170213
# ('probabl', '15'):0.02
# ('mind', 'long'):0.027777777777777776
# ('long', 'think'):0.007462686567164179
# ('think', 'oh'):0.008771929824561403
# ('oh', 'finish'):0.043478260869565216
# ('finish', 'there'):0.041666666666666664
# ('there', 'notabl'):0.010309278350515464
# ('notabl', 'differ'):0.25
# ('differ', 'second'):0.010752688172043012
# ('stori', 'go'):0.0019157088122605363
# ('go', 'rapid'):0.004830917874396135
# ('rapid', 'pace'):1.0
# ('pace', 'definit'):0.014492753623188406
# ('definit', 'move'):0.010416666666666666
# ('biggest', 'flaw'):0.045454545454545456
# ('flaw', 'act'):0.07692307692307693
# ('act', 'wise'):0.004524886877828055
# ('wise', 'cool'):0.125
# ('cool', 'noth'):0.02631578947368421
# ('noth', 'amaz'):0.013333333333333334
# ('amaz', 'someth'):0.0048543689320388345
# ('someth', 'haven'):0.00980392156862745
# ('seen', 'your'):0.007194244604316547
# ('your', 'familiar'):0.02631578947368421
# ('marvel', 'exact'):0.0010141987829614604
# ('exact', 'model'):0.1111111111111111
# ('model', 'move'):0.5
# ('move', 'famili'):0.0024390243902439024
# ('famili', 'thou'):0.010869565217391304
# ('widow', 'anna'):0.013513513513513514
# ('anna', 'good'):0.3333333333333333
# ('time', 'famili'):0.0036496350364963502
# ('famili', 'decent'):0.010869565217391304
# ('decent', 'watchabl'):0.02857142857142857
# ('watchabl', 'movi'):0.3333333333333333
# ('best', 'fresh'):0.0030211480362537764
# ('fresh', 'action'):0.02
# ('never', 'let'):0.0136986301369863
# ('let', 'term'):0.0196078431372549
# ('term', 'expect'):0.05555555555555555
# ('love', 'complet'):0.007326007326007326
# ('complet', 'say'):0.02
# ('say', 'full'):0.005988023952095809
# ('full', 'confid'):0.021739130434782608
# ('confid', 'movi'):0.1
# ('move', 'combin'):0.0024390243902439024
# ('combin', 'realli'):0.047619047619047616
# ('never', 'could'):0.0136986301369863
# ('could', 'expect'):0.008695652173913044
# ('expect', 'ever'):0.006097560975609756
# ('ever', 'movi'):0.014084507042253521
# ('littl', 'would'):0.009708737864077669
# ('theater', 'cast'):0.014084507042253521
# ('cast', 'music'):0.0064516129032258064
# ('music', 'choreographi'):0.017543859649122806
# ('choreographi', 'comedi'):0.007874015748031496
# ('relief', 'start'):0.03333333333333333
# ('strong', 'rush'):0.024390243902439025
# ('rush', 'feel'):0.05555555555555555
# ('feel', 'though'):0.004524886877828055
# ('movi', 'split'):0.0006807351940095302
# ('split', 'two'):0.5
# ('direct', 'halfway'):0.015625
# ('halfway', 'didn'):0.3333333333333333
# ('didn', 'justic'):0.007692307692307693
# ('justic', 'genet'):0.14285714285714285
# ('genet', 'super'):0.058823529411764705
# ('hero', 'stori'):0.009174311926605505
# ('fail', 'connect'):0.05555555555555555
# ('connect', 'emot'):0.023809523809523808
# ('emot', 'audienc'):0.008849557522123894
# ('audienc', 'seen'):0.02040816326530612
# ('seen', '6'):0.007194244604316547
# ('6', 'minut'):0.125
# ('minut', 'short'):0.03125
# ('short', 'aim'):0.038461538461538464
# ('aim', 'film'):0.16666666666666666
# ('film', 'name'):0.001059322033898305
# ('name', 'shelter'):0.037037037037037035
# ('shelter', 'could'):1.0
# ('could', 'connect'):0.008695652173913044
# ('connect', 'short'):0.023809523809523808
# ('howev', 'hi'):0.014925373134328358
# ('hi', 'long'):0.034482758620689655
# ('fail', 'get'):0.05555555555555555
# ('emot', 'connect'):0.008849557522123894
# ('good', 'look'):0.001838235294117647
# ('look', 'endless'):0.008064516129032258
# ('endless', 'action'):0.25
# ('sequenc', 'expect'):0.007575757575757576
# ('expect', 'two'):0.006097560975609756
# ('two', 'half'):0.010752688172043012
# ('half', 'year'):0.015873015873015872
# ('year', 'gap'):0.01
# ('gap', 'audienc'):0.16666666666666666
# ('audienc', 'came'):0.02040816326530612
# ('came', 'back'):0.06451612903225806
# ('togeth', 'watch'):0.022222222222222223
# ('pack', 'entertain'):0.03333333333333333
# ('keep', 'engag'):0.023255813953488372
# ('engag', 'till'):0.016666666666666666
# ('sequenc', 'visual'):0.007575757575757576
# ('effect', 'topnotch'):0.006711409395973154
# ('topnotch', 'costum'):0.2
# ('design', 'actor'):0.03125
# ('situ', 'like'):0.005780346820809248
# ('like', 'awkwafina'):0.001851851851851852
# ('awkwafina', 'theater'):0.006711409395973154
# ('theater', 'hous'):0.014084507042253521
# ('hous', 'india'):0.25
# ('india', 'movi'):0.3333333333333333
# ('movi', 'crazi'):0.0006807351940095302
# ('crazi', 'india'):0.045454545454545456
# ('india', 'one'):0.3333333333333333
# ('best', 'moral'):0.0030211480362537764
# ('moral', 'move'):0.1111111111111111
# ('move', '2'):0.0024390243902439024
# ('year', 'soft'):0.01
# ('soft', 'tomorrow'):0.25
# ('tomorrow', 'must'):0.5
# ('home', 'saw'):0.0625
# ('trailer', 'press'):0.027777777777777776
# ('press', 'movi'):0.2
# ('want', 'hope'):0.005988023952095809
# ('hope', 'in'):0.012048192771084338
# ('in', 'honest'):0.01680672268907563
# ('honest', 'saw'):0.05
# ('must', 'sayexpect'):0.01694915254237288
# ('sayexpect', 'blown'):1.0
# ('blown', 'water'):0.1
# ('water', 'movi'):0.09090909090909091
# ('great', 'someth'):0.0019569471624266144
# ('someth', 'quit'):0.00980392156862745
# ('quit', 'uniqu'):0.012345679012345678
# ('you', 'thoroughli'):0.0020876826722338203
# ('recommend', 'littl'):0.012987012987012988
# ('littl', 'differ'):0.009708737864077669
# ('marvel', 'moviesnew'):0.0010141987829614604
# ('moviesnew', 'cast'):1.0
# ('cast', 'total'):0.0064516129032258064
# ('total', 'amaz'):0.03333333333333333
# ('amaz', 'worth'):0.0048543689320388345
# ('move', 'lot'):0.007317073170731708
# ('good', 'blood'):0.001838235294117647
# ('blood', 'cell'):0.125
# ('cell', 'want'):0.3333333333333333
# ('see', 'masterpiec'):0.0028653295128939827
# ('masterpiec', 'there'):0.05263157894736842
# ('there', 'nose'):0.010309278350515464
# ('nose', 'start'):0.5
# ('start', 'bleed'):0.008547008547008548
# ('bleed', 'middl'):1.0
# ('middl', 'final'):0.03571428571428571
# ('fight', 'movi'):0.004210526315789474
# ('awesom', 'felt'):0.010526315789473684
# ('like', 'entir'):0.001851851851851852
# ('entir', 'differ'):0.02702702702702703
# ('experi', 'amaz'):0.017857142857142856
# ('amaz', 'chi'):0.009708737864077669
# ('chi', 'toni'):0.003125
# ('realli', 'shone'):0.002793296089385475
# ('shone', 'movi'):1.0
# ('definit', 'focus'):0.010416666666666666
# ('focus', 'introduc'):0.08333333333333333
# ('charact', 'unlik'):0.0015625
# ('unlik', 'peopl'):0.0625
# ('peopl', 'think'):0.009259259259259259
# ('think', 'solo'):0.008771929824561403
# ('move', 'set'):0.0024390243902439024
# ('set', 'must'):0.011235955056179775
# ('see', 'event'):0.0028653295128939827
# ('event', 'dont'):0.0625
# ('dont', 'understand'):0.006802721088435374
# ('understand', 'peopl'):0.06060606060606061
# ('star', 'hasn'):0.012987012987012988
# ('releas', 'major'):0.03571428571428571
# ('major', 'countri'):0.03125
# ('countri', 'peopl'):0.25
# ('peopl', 'hate'):0.009259259259259259
# ('hate', 'reason'):0.045454545454545456
# ('reason', 'realli'):0.03333333333333333
# ('in', 'fulton'):0.008403361344537815
# ('fulton', 'marvel'):1.0
# ('fan', 'usual'):0.00684931506849315
# ('wand', 'charact'):0.3333333333333333
# ('make', 'like'):0.0078125
# ('shangchi', 'time'):0.001976284584980237
# ('never', 'thought'):0.0136986301369863
# ('marvel', 'outdon'):0.0010141987829614604
# ('outdon', 'sure'):1.0
# ('sure', 'shangchi'):0.038461538461538464
# ('shangchi', 'basic'):0.001976284584980237
# ('fan', 'kind'):0.00684931506849315
# ('kind', 'know'):0.017543859649122806
# ('know', 'outlin'):0.007751937984496124
# ('outlin', 'film'):1.0
# ('pace', 'flow'):0.014492753623188406
# ('flow', 'realli'):0.047619047619047616
# ('well', 'kept'):0.0035211267605633804
# ('kept', 'audienc'):0.08333333333333333
# ('audienc', 'realli'):0.02040816326530612
# ('engag', 'what'):0.016666666666666666
# ('film', 'better'):0.001059322033898305
# ('seen', 'late'):0.007194244604316547
# ('late', 'stori'):0.05263157894736842
# ('stori', 'film'):0.0038314176245210726
# ('film', 'want'):0.001059322033898305
# ('anyth', 'super'):0.0196078431372549
# ('super', 'invest'):0.017857142857142856
# ('invest', 'best'):0.058823529411764705
# ('realli', 'perform'):0.002793296089385475
# ('perform', 'lead'):0.010752688172043012
# ('kate', 'movi'):0.013157894736842105
# ('everyth', 'you'):0.0196078431372549
# ('expect', 'top'):0.006097560975609756
# ('stori', 'peopl'):0.0019157088122605363
# ('peopl', 'le'):0.009259259259259259
# ('1', 'do'):0.038461538461538464
# ('do', 'fanboy'):0.043478260869565216
# ('fanboy', 'easili'):0.3333333333333333
# ('easili', 'better'):0.02564102564102564
# ('anyth', 'du'):0.0196078431372549
# ('du', 'put'):1.0
# ('put', 'hate'):0.020833333333333332
# ('hate', '2'):0.045454545454545456
# ('2', 'xenophob'):0.014084507042253521
# ('xenophob', '95'):1.0
# ('95', 'cast'):0.5
# ('cast', 'asia'):0.0064516129032258064
# ('asia', 'obvious'):0.006329113924050633
# ('obvious', '3'):0.1111111111111111
# ('3', 'chauvinist'):0.023255813953488372
# ('chauvinist', 'sever'):1.0
# ('sever', 'strong'):0.045454545454545456
# ('charact', '4'):0.0015625
# ('4', 'magna'):0.023255813953488372
# ('magna', 'see'):1.0
# ('see', '23'):0.0028653295128939827
# ('23', '5'):0.5
# ('5', 'comic'):0.03571428571428571
# ('book', 'puriti'):0.03125
# ('puriti', 'charact'):1.0
# ('charact', 'storylin'):0.0015625
# ('storylin', 'dont'):0.013888888888888888
# ('dont', 'follow'):0.006802721088435374
# ('follow', 'comic'):0.022222222222222223
# ('book', 'extent'):0.03125
# ('extent', 'insist'):0.3333333333333333
# ('insist', 'dont'):0.5
# ('dont', 'fall'):0.006802721088435374
# ('fall', 'categori'):0.02
# ('categori', 'realli'):0.25
# ('film', 'now'):0.001059322033898305
# ('scene', 'mixtur'):0.0019011406844106464
# ('mixtur', 'classic'):0.25
# ('choreographi', 'fli'):0.007874015748031496
# ('fli', 'float'):0.058823529411764705
# ('around', '1970'):0.022222222222222223
# ('1970', 'classic'):0.3333333333333333
# ('like', 'hidden'):0.001851851851851852
# ('dragon', 'crunch'):0.015873015873015872
# ('crunch', 'tiger'):1.0
# ('tiger', 'jet'):0.025
# ('jet', 'li'):1.0
# ('li', 'upon'):0.05555555555555555
# ('upon', 'time'):0.14285714285714285
# ('time', 'china'):0.0036496350364963502
# ('china', 'also'):0.037037037037037035
# ('also', 'realist'):0.0035335689045936395
# ('realist', 'fight'):0.25
# ('well', 'jacket'):0.0035211267605633804
# ('style', 'mixtur'):0.01639344262295082
# ('mixtur', 'fantasi'):0.25
# ('magic', 'power'):0.02127659574468085
# ('power', 'fight'):0.013513513513513514
# ('style', 'like'):0.01639344262295082
# ('like', 'dragon'):0.001851851851851852
# ('ball', 'll'):0.25
# ('ll', 'romanc'):0.08333333333333333
# ('romanc', 'scene'):0.14285714285714285
# ('scene', 'so'):0.0019011406844106464
# ('so', 'beauti'):0.25
# ('mother', 'father'):0.041666666666666664
# ('father', 'better'):0.01
# ('better', 'romanc'):0.006134969325153374
# ('romanc', 'movi'):0.14285714285714285
# ('movi', 'll'):0.0006807351940095302
# ('ll', 'landscap'):0.08333333333333333
# ('landscap', 'background'):0.1111111111111111
# ('background', 'graphic'):0.034482758620689655
# ('graphic', 'amaz'):0.07692307692307693
# ('amaz', 'well'):0.0048543689320388345
# ('done', 'so'):0.010416666666666666
# ('so', 'enjoy'):0.25
# ('landscap', 'grass'):0.1111111111111111
# ('grass', 'tree'):1.0
# ('tree', 'chine'):1.0
# ('creatur', 'funni'):0.023809523809523808
# ('watch', 'mostli'):0.002638522427440633
# ('mostli', 'kate'):0.043478260869565216
# ('shangchi', 'close'):0.001976284584980237
# ('friend', 'll'):0.017857142857142856
# ('ll', 'storylin'):0.08333333333333333
# ('storylin', '4'):0.013888888888888888
# ('4', 'main'):0.046511627906976744
# ('heal', 'went'):0.03333333333333333
# ('went', 'king'):0.008771929824561403
# ('li', 'well'):0.05555555555555555
# ('line', 'plot'):0.024390243902439025
# ('plot', '4'):0.007751937984496124
# ('show', 'flashback'):0.009433962264150943
# ('past', 'happen'):0.014492753623188406
# ('happen', '4'):0.03225806451612903
# ('4', 'charact'):0.023255813953488372
# ('charact', 'script'):0.0015625
# ('script', 'well'):0.03571428571428571
# ('done', 'seriou'):0.010416666666666666
# ('seriou', 'script'):0.05555555555555555
# ('script', 'wenwuxi'):0.03571428571428571
# ('wenwuxi', 'shangchi'):1.0
# ('2', 'funni'):0.014084507042253521
# ('funni', 'script'):0.00980392156862745
# ('script', 'kate'):0.03571428571428571
# ('kate', 'tremor'):0.013157894736842105
# ('flatteri', 'may'):0.1
# ('may', '2'):0.018518518518518517
# ('2', 'villain'):0.014084507042253521
# ('villain', 'work'):0.007874015748031496
# ('work', 'went'):0.008928571428571428
# ('made', 'job'):0.008264462809917356
# ('job', 'razorfist'):0.017543859649122806
# ('razorfist', 'death'):0.5
# ('dealer', 'sad'):0.16666666666666666
# ('sad', 'drama'):0.1111111111111111
# ('father', 'stuck'):0.01
# ('stuck', 'past'):0.3333333333333333
# ('past', 'wife'):0.014492753623188406
# ('wife', 'die'):0.0625
# ('die', 'long'):0.14285714285714285
# ('long', 'ago'):0.007462686567164179
# ('ago', 'heart'):0.1
# ('felt', 'heart'):0.006802721088435374
# ('heart', 'broken'):0.023255813953488372
# ('broken', 'plot'):0.16666666666666666
# ('shangchi', 'extrem'):0.001976284584980237
# ('entertain', 'twist'):0.01098901098901099
# ('turn', 'worldbuild'):0.022727272727272728
# ('worldbuild', 'spectacular'):0.25
# ('spectacular', 'charact'):0.027777777777777776
# ('written', 'depth'):0.043478260869565216
# ('depth', 'unlik'):0.02857142857142857
# ('phenomenon', 'can'):0.03571428571428571
# ('can', 'expect'):0.009345794392523364
# ('expect', 'solo'):0.006097560975609756
# ('solo', 'superhero'):0.043478260869565216
# ('perfect', 'scene'):0.010526315789473684
# ('great', 'graphic'):0.0019569471624266144
# ('graphic', 'work'):0.07692307692307693
# ('work', 'eye'):0.008928571428571428
# ('catch', 'dialogu'):0.14285714285714285
# ('dialogu', 'special'):0.03571428571428571
# ('special', 'joke'):0.013333333333333334
# ('joke', 'part'):0.013888888888888888
# ('part', 'great'):0.009259259259259259
# ('portray', 'famili'):0.045454545454545456
# ('drama', 'fantast'):0.023809523809523808
# ('fantast', 'way'):0.011363636363636364
# ('way', 'action'):0.005813953488372093
# ('scene', 'eye'):0.0019011406844106464
# ('eye', 'touch'):0.024390243902439025
# ('touch', 'also'):0.047619047619047616
# ('also', 'part'):0.0035335689045936395
# ('part', 'emot'):0.018518518518518517
# ('emot', 'almost'):0.008849557522123894
# ('almost', 'cri'):0.01639344262295082
# ('cri', 'still'):0.1
# ('still', 'watch'):0.010416666666666666
# ('movi', 'read'):0.0006807351940095302
# ('read', 'comment'):0.041666666666666664
# ('comment', 'first'):0.25
# ('first', 'suggest'):0.0049261083743842365
# ('suggest', 'plea'):0.2
# ('plea', 'dont'):0.037037037037037035
# ('miss', 'mid'):0.022222222222222223
# ('scene', 'mind'):0.0019011406844106464
# ('mind', 'donna'):0.027777777777777776
# ('donna', 'blow'):0.045454545454545456
# ('movi', 'serv'):0.0006807351940095302
# ('serv', 'introduct'):0.07692307692307693
# ('introduct', 'brand'):0.05555555555555555
# ('world', 'learn'):0.011111111111111112
# ('learn', 'sort'):0.05263157894736842
# ('sort', 'magic'):0.0625
# ('magic', 'place'):0.02127659574468085
# ('place', 'felt'):0.016129032258064516
# ('charact', 'way'):0.003125
# ('way', 'realli'):0.005813953488372093
# ('love', 'new'):0.003663003663003663
# ('new', 'place'):0.004761904761904762
# ('place', 'concept'):0.016129032258064516
# ('concept', 'realli'):0.06666666666666667
# ('charact', 'place'):0.0015625
# ('place', 'can'):0.016129032258064516
# ('can', 'understand'):0.009345794392523364
# ('rate', '10'):0.023255813953488372
# ('10', 'ok'):0.014285714285714285
# ('stori', 'suppos'):0.0019157088122605363
# ('suppos', 'laugh'):0.07692307692307693
# ('see', 'free'):0.0028653295128939827
# ('free', 'guy'):0.2222222222222222
# ('guy', '10'):0.025
# ('10', 'film'):0.014285714285714285
# ('movi', 'top'):0.0013614703880190605
# ('notch', 'new'):0.05
# ('world', 'explor'):0.011111111111111112
# ('explor', 'good'):0.0625
# ('fan', 'go'):0.0136986301369863
# ('amaz', 'goe'):0.0048543689320388345
# ('goe', 'straight'):0.03333333333333333
# ('straight', 'favourit'):0.07692307692307693
# ('movi', 'list'):0.0006807351940095302
# ('list', 'amaz'):0.1111111111111111
# ('line', 'great'):0.024390243902439025
# ('act', 'mesmeris'):0.004524886877828055
# ('mesmeris', 'cinematographi'):1.0
# ('humour', 'spectacular'):0.023255813953488372
# ('movi', 'everyon'):0.0006807351940095302
# ('everyon', 'must'):0.023809523809523808
# ('alway', 'astonish'):0.018867924528301886
# ('astonish', 'look'):0.25
# ('look', 'ahead'):0.008064516129032258
# ('ahead', 'time'):0.14285714285714285
# ('time', 'updat'):0.0036496350364963502
# ('updat', 'better'):0.5
# ('expect', 'toni'):0.006097560975609756
# ('toni', 'realli'):0.006944444444444444
# ('actor', 'consist'):0.009345794392523364
# ('consist', 'mani'):0.1
# ('asia', 'element'):0.006329113924050633
# ('scene', 'lit'):0.0019011406844106464
# ('lit', 'got'):0.25
# ('got', 'adrenalin'):0.011904761904761904
# ('adrenalin', 'feel'):0.3333333333333333
# ('feel', 'get'):0.004524886877828055
# ('like', 'john'):0.001851851851851852
# ('wick', '70'):0.16666666666666666
# ('70', 'film'):0.5
# ('film', 'choreographi'):0.001059322033898305
# ('choreographi', 'impress'):0.007874015748031496
# ('impress', 'gave'):0.017241379310344827
# ('gave', 'crouch'):0.034482758620689655
# ('dragon', 'kind'):0.015873015873015872
# ('kind', 'vice'):0.017543859649122806
# ('vice', 'time'):0.0625
# ('mean', 'far'):0.021739130434782608
# ('far', 'stori'):0.0136986301369863
# ('stori', 'set'):0.0019157088122605363
# ('next', 'chapter'):0.03333333333333333
# ('chapter', 'you'):0.25
# ('nice', 'that'):0.016666666666666666
# ('say', 'nospoil'):0.005988023952095809
# ('nospoil', 'in'):1.0
# ('in', 'marvel'):0.008403361344537815
# ('fan', 'unfortun'):0.00684931506849315
# ('unfortun', 'could'):0.047619047619047616
# ('widow', 'theater'):0.013513513513513514
# ('theater', 'right'):0.014084507042253521
# ('right', 'came'):0.015151515151515152
# ('came', 'went'):0.03225806451612903
# ('went', 'watch'):0.008771929824561403
# ('shangchi', 'say'):0.001976284584980237
# ('say', 'got'):0.005988023952095809
# ('got', 'cinema'):0.011904761904761904
# ('excit', 'first'):0.0125
# ('first', 'still'):0.0049261083743842365
# ('still', 'kind'):0.010416666666666666
# ('dinner', 'live'):0.014492753623188406
# ('noth', 'say'):0.013333333333333334
# ('say', 'special'):0.005988023952095809
# ('effect', 'combat'):0.006711409395973154
# ('though', 'amaz'):0.012987012987012988
# ('amaz', 'anyway'):0.0048543689320388345
# ('anyway', 'can'):0.1
# ('say', 'wast'):0.005988023952095809
# ('money', 'still'):0.05555555555555555
# ('still', 'nice'):0.010416666666666666
# ('nice', 'movi'):0.03333333333333333
# ('know', 'peopl'):0.015503875968992248
# ('might', 'like'):0.027777777777777776
# ('like', 'doesn'):0.001851851851851852
# ('even', 'seem'):0.004878048780487805
# ('movi', 'imag'):0.0006807351940095302
# ('imag', 'film'):0.14285714285714285
# ('uniqu', 'marvel'):0.020833333333333332
# ('marvel', 'beauti'):0.0010141987829614604
# ('beauti', 'plot'):0.006329113924050633
# ('plot', 'leav'):0.007751937984496124
# ('much', 'desir'):0.003676470588235294
# ('desir', 'sang'):0.5
# ('sister', 'probabl'):0.02127659574468085
# ('best', 'develop'):0.0030211480362537764
# ('hope', 'futur'):0.024096385542168676
# ('futur', 'move'):0.018518518518518517
# ('move', 'develop'):0.0024390243902439024
# ('develop', 'awkwafina'):0.013888888888888888
# ('charact', 'hilari'):0.0015625
# ('hilari', 'want'):0.05263157894736842
# ('much', 'first'):0.003676470588235294
# ('first', 'heard'):0.0049261083743842365
# ('heard', 'storylin'):0.08333333333333333
# ('one', 'kind'):0.002150537634408602
# ('kind', 'definit'):0.017543859649122806
# ('definit', 'enjoy'):0.020833333333333332
# ('chi', 'must'):0.003125
# ('vex', 'love'):0.043478260869565216
# ('move', 'far'):0.0024390243902439024
# ('far', 'realli'):0.0136986301369863
# ('realli', 'need'):0.002793296089385475
# ('need', 'part'):0.013157894736842105
# ('part', 'tow'):0.009259259259259259
# ('tow', 'realli'):0.3333333333333333
# ('written', 'well'):0.08695652173913043
# ('well', 'much'):0.0035211267605633804
# ('movi', 'anaem'):0.0006807351940095302
# ('anaem', 'surpris'):0.16666666666666666
# ('lover', 'simpli'):0.3333333333333333
# ('simpli', 'genet'):0.043478260869565216
# ('genet', 'joke'):0.058823529411764705
# ('joke', 'dont'):0.027777777777777776
# ('dont', 'land'):0.013605442176870748
# ('land', 'recommend'):0.05263157894736842
# ('recommend', 'mayb'):0.012987012987012988
# ('mayb', 'wait'):0.025
# ('wait', 'stream'):0.0136986301369863
# ('stream', 'movi'):0.25
# ('hand', 'brilliant'):0.020833333333333332
# ('brilliant', 'thank'):0.02857142857142857
# ('marvel', 'give'):0.0010141987829614604
# ('world', 'excel'):0.011111111111111112
# ('excel', 'everyon'):0.02
# ('everyon', 'situ'):0.023809523809523808
# ('lie', 'star'):0.006060606060606061
# ('star', 'long'):0.012987012987012988
# ('go', 'best'):0.00966183574879227
# ('choic', 'role'):0.0625
# ('perfect', 'allot'):0.010526315789473684
# ('allot', 'action'):0.3333333333333333
# ('action', 'plu'):0.0019120458891013384
# ('plu', 'allot'):0.047619047619047616
# ('allot', 'comedi'):0.3333333333333333
# ('comedi', 'funniest'):0.008771929824561403
# ('funniest', 'marvel'):0.25
# ('ever', 'also'):0.014084507042253521
# ('also', 'storylin'):0.0035335689045936395
# ('consid', 'movi'):0.045454545454545456
# ('comic', 'movi'):0.012987012987012988
# ('job', 'rotten'):0.017543859649122806
# ('rotten', 'potato'):1.0
# ('potato', 'make'):0.5
# ('like', 'level'):0.001851851851851852
# ('level', 'spiderman'):0.02631578947368421
# ('2', 'dark'):0.014084507042253521
# ('knight', 'even'):0.25
# ('close', 'level'):0.03571428571428571
# ('level', 'basic'):0.02631578947368421
# ('basic', 'you'):0.045454545454545456
# ('stori', 'possibl'):0.0019157088122605363
# ('what', 'point'):0.05555555555555555
# ('point', 'score'):0.011235955056179775
# ('score', 'one'):0.022222222222222223
# ('masterpiec', 'spiderman'):0.05263157894736842
# ('2', 'anoth'):0.014084507042253521
# ('anoth', 'super'):0.005681818181818182
# ('super', 'mediocr'):0.017857142857142856
# ('mediocr', 'shangschi'):0.045454545454545456
# ('shangschi', 'rotten'):1.0
# ('potato', 'score'):0.5
# ('sen', 'didn'):0.024390243902439025
# ('anyth', 'film'):0.0196078431372549
# ('like', 'dr'):0.001851851851851852
# ('strang', 'want'):0.043478260869565216
# ('want', 'beauti'):0.005988023952095809
# ('visual', 'brilliant'):0.005291005291005291
# ('time', 'yeah'):0.0036496350364963502
# ('find', 'someth'):0.021739130434782608
# ('marvel', 'new'):0.0010141987829614604
# ('concept', 'new'):0.13333333333333333
# ('new', 'storylin'):0.004761904761904762
# ('storylin', 'new'):0.013888888888888888
# ('new', 'type'):0.009523809523809525
# ('power', 'wait'):0.013513513513513514
# ('wait', 'star'):0.0136986301369863
# ('star', 'stori'):0.012987012987012988
# ('line', 'weak'):0.024390243902439025
# ('weak', 'donna'):0.034482758620689655
# ('donna', 'disappoint'):0.09090909090909091
# ('disappoint', 'stori'):0.013888888888888888
# ('that', 'reduc'):0.022988505747126436
# ('reduc', '2'):0.5
# ('star', 'direct'):0.012987012987012988
# ('action', 'anoth'):0.0019120458891013384
# ('level', 'that'):0.02631578947368421
# ('that', 'give'):0.04597701149425287
# ('give', '2'):0.019801980198019802
# ('star', 'act'):0.025974025974025976
# ('act', 'can'):0.00904977375565611
# ('can', 'find'):0.018691588785046728
# ('find', 'mistak'):0.021739130434782608
# ('mistak', 'actor'):0.1
# ('actor', 'na'):0.009345794392523364
# ('na', 'acr'):1.0
# ('acr', 'done'):1.0
# ('done', 'job'):0.020833333333333332
# ('well', '1'):0.0035211267605633804
# ('star', 'import'):0.025974025974025976
# ('import', 'thing'):0.0625
# ('marvel', 'emot'):0.0010141987829614604
# ('emot', 'know'):0.017699115044247787
# ('charact', 'fictionalbut'):0.0015625
# ('fictionalbut', 'emot'):1.0
# ('attach', 'movi'):0.2857142857142857
# ('emot', 'that'):0.008849557522123894
# ('reduc', '1'):0.25
# ('star', 'last'):0.012987012987012988
# ('last', '1'):0.014492753623188406
# ('star', 'marvel'):0.012987012987012988
# ('fan', 'yeah'):0.00684931506849315
# ('yeah', 'histori'):0.017857142857142856
# ('histori', 'marvel'):0.047619047619047616
# ('star', 'wait'):0.025974025974025976
# ('wait', 'donna'):0.0136986301369863
# ('disappoint', 'storylin'):0.013888888888888888
# ('storylin', 'like'):0.013888888888888888
# ('stori', 'can'):0.0019157088122605363
# ('can', 'attach'):0.009345794392523364
# ('attach', 'u'):0.14285714285714285
# ('u', 'like'):0.014925373134328358
# ('movi', 'donna'):0.0006807351940095302
# ('donna', 'reduc'):0.045454545454545456
# ('wait', 'dont'):0.0136986301369863
# ('worri', 'action'):0.0625
# ('effect', 'direct'):0.006711409395973154
# ('direct', 'awesom'):0.015625
# ('awesom', 'good'):0.010526315789473684
# ('good', 'that'):0.001838235294117647
# ('find', 'singl'):0.021739130434782608
# ('singl', 'mistak'):0.043478260869565216
# ('mistak', 'act'):0.1
# ('act', 'done'):0.004524886877828055
# ('well', 'that'):0.0035211267605633804
# ('thing', 'emot'):0.005988023952095809
# ('charact', 'section'):0.0015625
# ('section', 'know'):0.14285714285714285
# ('movi', 'weak'):0.0013614703880190605
# ('can', 'get'):0.009345794392523364
# ('charact', 'easili'):0.0015625
# ('easili', '1'):0.02564102564102564
# ('star', 'reduc'):0.012987012987012988
# ('reduc', 'bc'):0.25
# ('bc', '1'):0.5
# ('star', 'ad'):0.012987012987012988
# ('ad', 'be'):0.043478260869565216
# ('be', 'marvel'):0.25
# ('year', 'till'):0.01
# ('till', 'like'):0.06666666666666667
# ('like', 'best'):0.001851851851851852
# ('2021', 'say'):0.038461538461538464
# ('say', 'must'):0.005988023952095809
# ('great', 'movabl'):0.0019569471624266144
# ('enjoy', 'experienc'):0.005154639175257732
# ('experienc', 'big'):0.125
# ('screen', 'watch'):0.011363636363636364
# ('chi', 'almost'):0.003125
# ('almost', 'immedi'):0.01639344262295082
# ('immedi', 'see'):0.14285714285714285
# ('see', 'follow'):0.0028653295128939827
# ('formula', 'everi'):0.022222222222222223
# ('excess', 'choreographi'):0.09090909090909091
# ('choreographi', 'choreographi'):0.007874015748031496
# ('univers', 'mayb'):0.008130081300813009
# ('cinema', 'gener'):0.0125
# ('gener', 'charact'):0.02631578947368421
# ('chi', 'play'):0.003125
# ('say', 'charact'):0.005988023952095809
# ('especi', 'charact'):0.010638297872340425
# ('charact', 'katyplay'):0.0015625
# ('katyplay', 'awkwafina'):1.0
# ('flat', 'childish'):0.07142857142857142
# ('childish', 'make'):0.3333333333333333
# ('make', 'almost'):0.00390625
# ('almost', 'annoy'):0.01639344262295082
# ('annoy', 'though'):0.045454545454545456
# ('though', 'believ'):0.012987012987012988
# ('believ', 'fault'):0.022222222222222223
# ('fault', 'writer'):0.2
# ('writer', 'awkwafina'):0.07142857142857142
# ('awkwafina', 'anoth'):0.006711409395973154
# ('anoth', 'aspect'):0.005681818181818182
# ('like', 'cameo'):0.001851851851851852
# ('cameo', 'mention'):0.037037037037037035
# ('mention', 'avoid'):0.03571428571428571
# ('soiler', 'say'):0.125
# ('say', 'definit'):0.005988023952095809
# ('favorit', 'part'):0.03125
# ('you', 'gener'):0.0020876826722338203
# ('gener', 'give'):0.02631578947368421
# ('shangchi', '9'):0.001976284584980237
# ('10', 'great'):0.014285714285714285
# ('see', 'fresh'):0.0028653295128939827
# ('fresh', 'marvel'):0.04
# ('charact', 'design'):0.0015625
# ('design', 'could'):0.03125
# ('could', 'improv'):0.008695652173913044
# ('improv', 'bit'):0.25
# ('bit', 'compar'):0.010526315789473684
# ('compar', 'de'):0.034482758620689655
# ('de', 'aquaman'):0.2
# ('aquaman', 'still'):0.25
# ('still', 'aquaman'):0.010416666666666666
# ('aquaman', 'win'):0.25
# ('win', 'peopl'):0.08333333333333333
# ('peopl', 'vote'):0.009259259259259259
# ('vote', '810'):0.5
# ('810', 'ray'):0.06666666666666667
# ('ray', 'stori'):0.1
# ('line', 'primit'):0.024390243902439025
# ('primit', 'gap'):1.0
# ('fill', 'martial'):0.03571428571428571
# ('art', 'legend'):0.005319148936170213
# ('ring', 'legend'):0.0044444444444444444
# ('legend', 'ring'):0.008
# ('give', 'super'):0.0049504950495049506
# ('power', 'see'):0.013513513513513514
# ('see', 'beg'):0.0028653295128939827
# ('beg', 'movi'):0.3333333333333333
# ('end', 'produc'):0.0049261083743842365
# ('produc', 'ad'):0.0625
# ('ad', 'ben'):0.043478260869565216
# ('dingley', 'benedict'):0.03333333333333333
# ('long', 'tailor'):0.007462686567164179
# ('tailor', 'shangchi'):1.0
# ('feel', 'disconnect'):0.004524886877828055
# ('disconnect', 'like'):0.5
# ('like', 'billi'):0.001851851851851852
# ('billi', 'bob'):1.0
# ('bob', 'thornton'):0.5
# ('thornton', 'santa'):1.0
# ('santa', 'bad'):0.3333333333333333
# ('bad', 'santa'):0.008
# ('santa', 'mitchel'):0.3333333333333333
# ('yeah', 'play'):0.017857142857142856
# ('play', 'crouch'):0.01098901098901099
# ('tiger', 'sad'):0.025
# ('sad', 'hollywood'):0.1111111111111111
# ('hollywood', 'give'):0.038461538461538464
# ('give', 'nonkungfu'):0.0049504950495049506
# ('nonkungfu', 'role'):1.0
# ('role', 'talent'):0.011904761904761904
# ('talent', 'sure'):0.07692307692307693
# ('sure', 'short'):0.019230769230769232
# ('short', 'the'):0.038461538461538464
# ('the', 'start'):0.1
# ('start', 'check'):0.008547008547008548
# ('check', 'watch'):0.06666666666666667
# ('thing', 'bore'):0.005988023952095809
# ('bore', 'want'):0.016129032258064516
# ('seen', 'review'):0.007194244604316547
# ('review', 'say'):0.016129032258064516
# ('say', 'fight'):0.005988023952095809
# ('fight', 'terribl'):0.002105263157894737
# ('terribl', 'stori'):0.05555555555555555
# ('stori', 'hard'):0.0019157088122605363
# ('hard', 'follow'):0.05714285714285714
# ('follow', 'none'):0.022222222222222223
# ('none', 'true'):0.1
# ('true', 'fight'):0.037037037037037035
# ('intens', 'stori'):0.08333333333333333
# ('stori', 'work'):0.0019157088122605363
# ('art', 'can'):0.005319148936170213
# ('etern', 'futur'):0.1
# ('futur', 'product'):0.018518518518518517
# ('product', '1010'):0.029411764705882353
# ('movi', 'matter'):0.0006807351940095302
# ('matter', 'anyon'):0.06666666666666667
# ('miss', 'lot'):0.022222222222222223
# ('action', 'follow'):0.0019120458891013384
# ('follow', 'sad'):0.022222222222222223
# ('sad', 'stori'):0.1111111111111111
# ('son', 'like'):0.038461538461538464
# ('next', 'bit'):0.016666666666666666
# ('bit', 'problem'):0.010526315789473684
# ('problem', 'is'):0.030303030303030304
# ('is', 'joke'):0.06666666666666667
# ('land', 'feel'):0.05263157894736842
# ('long', 'part'):0.007462686567164179
# ('emot', 'beat'):0.008849557522123894
# ('beat', 'beauti'):0.1111111111111111
# ('beauti', 'good'):0.012658227848101266
# ('5', 'best'):0.03571428571428571
# ('good', 'mouth'):0.001838235294117647
# ('mouth', 'open'):0.2
# ('wide', 'watch'):0.1111111111111111
# ('ok', 'want'):0.034482758620689655
# ('chi', 'nice'):0.003125
# ('nice', 'characternow'):0.016666666666666666
# ('characternow', '30'):1.0
# ('realli', 'slow'):0.002793296089385475
# ('slow', 'didn'):0.02702702702702703
# ('would', 'person'):0.005952380952380952
# ('person', 'give'):0.013888888888888888
# ('give', '4'):0.0049504950495049506
# ('4', '10'):0.023255813953488372
# ('final', 'hero'):0.01098901098901099
# ('hero', 'asia'):0.009174311926605505
# ('asia', 'perfect'):0.006329113924050633
# ('far', 'fight'):0.0136986301369863
# ('beauti', 'shown'):0.006329113924050633
# ('shown', 'also'):0.058823529411764705
# ('also', 'predict'):0.0035335689045936395
# ('made', 'amaz'):0.008264462809917356
# ('cinema', 'far'):0.0125
# ('far', 'wait'):0.0136986301369863
# ('next', 'sang'):0.016666666666666666
# ('enjoy', 'short'):0.005154639175257732
# ('short', 'shown'):0.038461538461538464
# ('shown', 'pretti'):0.058823529411764705
# ('big', 'cameo'):0.010309278350515464
# ('cameo', 'thing'):0.037037037037037035
# ('thing', 'trailer'):0.005988023952095809
# ('movi', 'offer'):0.0006807351940095302
# ('offer', 'littl'):0.058823529411764705
# ('littl', 'whole'):0.009708737864077669
# ('whole', 'underground'):0.013888888888888888
# ('ring', 'bare'):0.0044444444444444444
# ('bare', 'explor'):0.14285714285714285
# ('explor', 'explain'):0.0625
# ('explain', 'realli'):0.05555555555555555
# ('nice', 'choreograph'):0.016666666666666666
# ('scene', 'ruin'):0.0019011406844106464
# ('ruin', 'top'):0.07142857142857142
# ('chi', 'explos'):0.003125
# ('explos', 'one'):0.3333333333333333
# ('point', 'thought'):0.011235955056179775
# ('thought', 'watch'):0.012195121951219513
# ('watch', 'transform'):0.002638522427440633
# ('transform', 'sequel'):0.2
# ('sequel', 'wors'):0.05
# ('wors', 'part'):0.1111111111111111
# ('part', 'probabl'):0.009259259259259259
# ('probabl', 'fact'):0.02
# ('fact', 'shoehorn'):0.020833333333333332
# ('shoehorn', 'you'):0.25
# ('you', 'link'):0.0020876826722338203
# ('link', 'use'):0.08333333333333333
# ('much', 'conveni'):0.003676470588235294
# ('conveni', 'plot'):0.06666666666666667
# ('plot', 'devic'):0.007751937984496124
# ('devic', 'get'):0.5
# ('get', 'imposs'):0.0049504950495049506
# ('imposs', 'find'):0.25
# ('place', 'easi'):0.016129032258064516
# ('easi', 'bare'):0.07692307692307693
# ('bare', 'inconveni'):0.14285714285714285
# ('inconveni', 'well'):1.0
# ('put', 'exact'):0.020833333333333332
# ('exact', 'place'):0.1111111111111111
# ('place', 'guy'):0.016129032258064516
# ('guy', 'magic'):0.025
# ('magic', 'sat'):0.02127659574468085
# ('sat', 'navi'):0.25
# ('navi', 'use'):1.0
# ('use', 'bow'):0.010526315789473684
# ('bow', 'get'):0.14285714285714285
# ('get', 'ad'):0.0049504950495049506
# ('ad', 'money'):0.043478260869565216
# ('money', 'boy'):0.05555555555555555
# ('boy', 'felt'):0.1111111111111111
# ('felt', 'predict'):0.006802721088435374
# ('predict', 'lazi'):0.016129032258064516
# ('lazi', 'said'):0.25
# ('said', 'fight'):0.020833333333333332
# ('fight', 'enjoy'):0.002105263157894737
# ('half', 'saw'):0.015873015873015872
# ('saw', 'dragon'):0.02564102564102564
# ('dragon', 'averag'):0.015873015873015872
# ('averag', '610'):0.03571428571428571
# ('610', 'storylin'):0.14285714285714285
# ('storylin', 'predict'):0.013888888888888888
# ('predict', 'noth'):0.016129032258064516
# ('noth', 'innov'):0.02666666666666667
# ('innov', 'creativ'):0.3333333333333333
# ('creativ', 'stori'):0.058823529411764705
# ('noth', 'ordinari'):0.013333333333333334
# ('ordinari', 'base'):0.2
# ('base', 'similar'):0.047619047619047616
# ('similar', 'move'):0.09090909090909091
# ('move', 'watch'):0.0024390243902439024
# ('time', 'noth'):0.0036496350364963502
# ('noth', 'leav'):0.013333333333333334
# ('leav', 'impress'):0.023255813953488372
# ('impress', 'actor'):0.017241379310344827
# ('job', 'back'):0.017543859649122806
# ('back', 'engag'):0.010752688172043012
# ('engag', 'storylin'):0.016666666666666666
# ('storylin', 'main'):0.013888888888888888
# ('main', 'conflict'):0.014492753623188406
# ('conflict', 'film'):0.07142857142857142
# ('film', 'begin'):0.001059322033898305
# ('begin', 'x'):0.022727272727272728
# ('shangchi', 'train'):0.001976284584980237
# ('lung', 'sinc'):0.006134969325153374
# ('child', '14'):0.0625
# ('14', 'order'):0.25
# ('order', 'commit'):0.1
# ('commit', 'first'):0.5
# ('first', 'murder'):0.0049261083743842365
# ('murder', 'howev'):0.3333333333333333
# ('howev', 'later'):0.014925373134328358
# ('later', 'took'):0.045454545454545456
# ('took', 'advantag'):0.045454545454545456
# ('advantag', 'leav'):0.25
# ('leav', 'father'):0.023255813953488372
# ...
# ('movi', 'bazaar'):0.0006807351940095302
# ('bazaar', 'gooooood'):0.3333333333333333
# ('gooooood', 'job'):1.0
# ('movi', 'sooooo'):0.0006807351940095302
# ('sooooo', 'epic'):1.0
# ('epic', 'beauti'):0.023809523809523808
# ('good', 'storylin'):0.001838235294117647
# ('storylin', 'realli'):0.013888888888888888
# ('impress', 'charact'):0.017241379310344827
# ('total', 'wast'):0.03333333333333333
# ('time', 'iron'):0.0036496350364963502
# ('man', '2008'):0.01282051282051282
# ('2008', 'much'):0.16666666666666666
# ('better', 'me'):0.006134969325153374
# ('me', 'never'):0.2
# ('music', 'enhanc'):0.017543859649122806
# ('enhanc', 'experi'):0.25
# ('experi', 'tenfold'):0.017857142857142856
# ('tenfold', 'movi'):0.5
# ('masterpiec', 'marvel'):0.05263157894736842
# ('ring', 'latest'):0.0044444444444444444
# ('latest', 'modernday'):0.1111111111111111
# ('modernday', 'extens'):1.0
# ('extens', 'you'):0.25
# ('you', 'guid'):0.0020876826722338203
# ('guid', 'craft'):0.16666666666666666
# ('craft', 'beauti'):0.2
# ('beauti', 'destini'):0.006329113924050633
# ('shangchi', 'massiv'):0.001976284584980237
# ('massiv', 'soul'):0.07692307692307693
# ('soul', 'futur'):0.07692307692307693
# ('move', 'need'):0.0024390243902439024
# ('need', 'take'):0.013157894736842105
# ('note', 'black'):0.06666666666666667
# ('anoth', 'memor'):0.005681818181818182
# ('memor', 'occur'):0.07142857142857142
# ('occur', 'watch'):0.3333333333333333
# ('movi', 'genuin'):0.0006807351940095302
# ('genuin', 'longer'):0.05555555555555555
# ('longer', 'charact'):0.16666666666666666
# ('charact', 'focu'):0.0015625
# ('focu', 'adventur'):0.06666666666666667
# ('adventur', 'toward'):0.019230769230769232
# ('toward', 'locat'):0.05555555555555555
# ('locat', 'follow'):0.1111111111111111
# ('adventur', 'amaz'):0.019230769230769232
# ('amaz', 'superhero'):0.0048543689320388345
# ('superhero', 'orient'):0.007462686567164179
# ('orient', 'fantasi'):0.16666666666666666
# ('fantasi', 'blockbust'):0.01639344262295082
# ('blockbust', 'notic'):0.041666666666666664
# ('notic', 'vex'):0.08333333333333333
# ('vex', 'scene'):0.043478260869565216
# ('design', 'special'):0.03125
# ('incred', 'heighten'):0.014925373134328358
# ('heighten', 'impact'):1.0
# ('impact', 'movi'):0.07692307692307693
# ('movi', 'allow'):0.0006807351940095302
# ('allow', 'symbol'):0.08333333333333333
# ('symbol', 'impact'):0.3333333333333333
# ('impact', 'aweinspir'):0.07692307692307693
# ('aweinspir', 'product'):0.3333333333333333
# ('valu', 'result'):0.09090909090909091
# ('result', 'aforement'):0.1
# ('aforement', 'movi'):0.3333333333333333
# ('movi', 'knock'):0.0006807351940095302
# ('knock', 'dazzl'):0.14285714285714285
# ('dazzl', 'height'):0.1111111111111111
# ('height', 'beauti'):1.0
# ('beauti', 'scale'):0.006329113924050633
# ('scale', 'vex'):0.2
# ('vex', 'movement'):0.043478260869565216
# ('movement', 'sequenc'):0.0625
# ('choreographi', 'polish'):0.007874015748031496
# ('polish', 'stun'):0.16666666666666666
# ('stun', 'narr'):0.01818181818181818
# ('narr', 'storylin'):0.0625
# ('storylin', 'continu'):0.013888888888888888
# ('continu', 'incred'):0.03571428571428571
# ('incred', 'understand'):0.014925373134328358
# ('understand', 'moment'):0.030303030303030304
# ('humour', 'you'):0.023255813953488372
# ('you', 'wellknown'):0.0020876826722338203
# ('wellknown', 'film'):1.0
# ('film', 'divid'):0.001059322033898305
# ('divid', 'go'):1.0
# ('cinema', 'wait'):0.0125
# ('wait', 'digit'):0.0136986301369863
# ('digit', 'compon'):0.3333333333333333
# ('compon', 'covid19'):0.5
# ('covid19', 'howev'):0.3333333333333333
# ('howev', 'didn'):0.014925373134328358
# ('need', 'entireti'):0.013157894736842105
# ('entireti', 'shangchi'):0.5
# ('shangchi', 'spoil'):0.001976284584980237
# ('spoil', 'earlier'):0.043478260869565216
# ('earlier', 'lead'):0.14285714285714285
# ('lead', 'thank'):0.018518518518518517
# ('thank', 'good'):0.02564102564102564
# ('good', 'went'):0.001838235294117647
# ('went', 'first'):0.008771929824561403
# ('show', 'open'):0.009433962264150943
# ('open', 'thursday'):0.02702702702702703
# ('thursday', 'night'):0.5
# ('night', 'experienc'):0.07142857142857142
# ('experienc', 'shangchi'):0.125
# ('shangchi', 'sever'):0.001976284584980237
# ('time', 'extraordinarili'):0.0036496350364963502
# ('extraordinarili', 'differ'):1.0
# ('differ', 'format'):0.010752688172043012
# ('format', 'includ'):0.2
# ('includ', 'do'):0.04
# ('movi', 'display'):0.0006807351940095302
# ('display', 'remark'):0.1
# ('remark', 'phenomenon'):0.1
# ('phenomenon', 'combat'):0.03571428571428571
# ('combat', 'perform'):0.03571428571428571
# ('perform', 'marvel'):0.010752688172043012
# ('seen', 'notic'):0.007194244604316547
# ('notic', 'approach'):0.08333333333333333
# ('approach', 'previous'):0.1
# ('previous', 'movi'):0.125
# ('formula', 'welltrodden'):0.022222222222222223
# ('welltrodden', 'territori'):1.0
# ('territori', 'marvel'):0.16666666666666666
# ('marvel', 'sever'):0.0010141987829614604
# ('sever', 'except'):0.045454545454545456
# ('except', 'visual'):0.027777777777777776
# ('effect', 'layer'):0.006711409395973154
# ('layer', 'shangchi'):0.07142857142857142
# ('shangchi', 'enchant'):0.001976284584980237
# ('enchant', 'movi'):0.3333333333333333
# ('better', 'biggest'):0.006134969325153374
# ('screen', 'find'):0.011363636363636364
# ('find', 'keep'):0.021739130434782608
# ('keep', 'safeti'):0.023255813953488372
# ('safeti', 'mind'):1.0
# ('mind', 'time'):0.027777777777777776
# ('time', 'seen'):0.0036496350364963502
# ('move', 'consist'):0.0024390243902439024
# ('consist', 'you'):0.1
# ('you', 'got'):0.0020876826722338203
# ('got', 'know'):0.011904761904761904
# ('know', 'narr'):0.007751937984496124
# ('narr', 'predict'):0.0625
# ('predict', 'storylin'):0.016129032258064516
# ('superhero', 'foundat'):0.007462686567164179
# ('foundat', 'adventur'):1.0
# ('full', 'numer'):0.021739130434782608
# ('numer', 'great'):0.2
# ('great', 'moment'):0.0019569471624266144
# ('moment', 'battl'):0.010101010101010102
# ('battl', 'sequenc'):0.016129032258064516
# ('piec', 'arguabl'):0.037037037037037035
# ('arguabl', 'undoubtedli'):0.25
# ('attract', 'shangchi'):0.16666666666666666
# ('shangchi', 'given'):0.001976284584980237
# ('u', 'outstand'):0.014925373134328358
# ('outstand', 'person'):0.05555555555555555
# ('charact', 'liveact'):0.0015625
# ('liveact', 'film'):0.2
# ('planter', 'solitari'):0.3333333333333333
# ('solitari', 'quest'):1.0
# ('quest', 'marvel'):0.25
# ('except', 'superhero'):0.027777777777777776
# ('year', 'past'):0.01
# ('past', 'decad'):0.014492753623188406
# ('decad', 'situ'):0.125
# ('lie', 'meager'):0.006060606060606061
# ('wa', 'get'):0.037037037037037035
# ('get', 'consider'):0.0049504950495049506
# ('consider', 'distinct'):1.0
# ('distinct', 'except'):0.07692307692307693
# ('except', 'choreograph'):0.027777777777777776
# ('choreographi', 'wit'):0.007874015748031496
# ('wit', 'sinc'):0.5
# ('soldier', 'one'):0.05263157894736842
# ('shangchi', 'seen'):0.001976284584980237
# ('fresh', 'shangchi'):0.02
# ('need', 'u'):0.013157894736842105
# ('u', 'depriv'):0.014925373134328358
# ('depriv', 'tradit'):1.0
# ('tradit', 'antiqu'):0.043478260869565216
# ('antiqu', 'sequenc'):1.0
# ('martial', 'craftsmanship'):0.005405405405405406
# ('craftsmanship', 'appreci'):1.0
# ('lot', 'audienc'):0.00546448087431694
# ('audienc', 'applaud'):0.02040816326530612
# ('applaud', 'incred'):1.0
# ('incred', 'modern'):0.014925373134328358
# ('modern', 'deduct'):0.04
# ('deduct', 'one'):0.5
# ('better', 'except'):0.006134969325153374
# ('except', 'marvel'):0.027777777777777776
# ('ever', 'would'):0.014084507042253521
# ('pretti', 'cool'):0.011494252873563218
# ('cool', 'there'):0.02631578947368421
# ('much', 'talk'):0.003676470588235294
# ('talk', 'act'):0.047619047619047616
# ('averag', 'stori'):0.03571428571428571
# ('stori', 'simpli'):0.0019157088122605363
# ('simpli', 'interest'):0.043478260869565216
# ('interest', 'person'):0.011904761904761904
# ('dont', 'hate'):0.006802721088435374
# ('mean', 'mauric'):0.021739130434782608
# ('mauric', 'pretti'):1.0
# ('pretti', 'cut'):0.011494252873563218
# ('cut', 'haven'):0.034482758620689655
# ('seen', 'wouldn'):0.007194244604316547
# ('wouldn', 'recommend'):0.08333333333333333
# ('worth', 'moneytim'):0.013513513513513514
# ('moneytim', '10'):1.0
# ('10', 'toni'):0.014285714285714285
# ('lung', 'lead'):0.006134969325153374
# ('lead', 'whole'):0.018518518518518517
# ('whole', 'storylin'):0.013888888888888888
# ('storylin', 'best'):0.013888888888888888
# ('long', 'come'):0.007462686567164179
# ('come', 'asia'):0.006944444444444444
# ('american', 'upbring'):0.029411764705882353
# ('upbring', 'saw'):0.3333333333333333
# ('saw', 'part'):0.02564102564102564
# ('stori', 'play'):0.0019157088122605363
# ('screen', 'there'):0.011363636363636364
# ('there', 'someth'):0.010309278350515464
# ('someth', 'affirm'):0.00980392156862745
# ('affirm', 'beauti'):0.5
# ('beauti', 'see'):0.006329113924050633
# ('see', 'part'):0.0028653295128939827
# ('want', 'peopl'):0.005988023952095809
# ('peopl', 'understand'):0.009259259259259259
# ('understand', 'full'):0.030303030303030304
# ('full', 'display'):0.021739130434782608
# ('display', 'toni'):0.1
# ('lung', 'specif'):0.006134969325153374
# ('specif', 'wonder'):0.1
# ('job', 'depict'):0.017543859649122806
# ('depict', 'complex'):0.5
# ('complex', 'father'):0.05263157894736842
# ('father', 'someth'):0.01
# ('someth', 'relat'):0.00980392156862745
# ('relat', 'shape'):0.07142857142857142
# ('shape', 'form'):0.16666666666666666
# ('form', 'marvel'):0.16666666666666666
# ('need', 'invest'):0.013157894736842105
# ('invest', 'franchis'):0.058823529411764705
# ('franchis', 'heavili'):0.03333333333333333
# ('heavili', 'movi'):0.14285714285714285
# ('away', 'express'):0.01639344262295082
# ('express', 'chine'):0.09090909090909091
# ('cultur', 'beauti'):0.008264462809917356
# ('made', 'top'):0.008264462809917356
# ('list', 'love'):0.1111111111111111
# ('inspir', 'mani'):0.03571428571428571
# ('mani', 'young'):0.0070921985815602835
# ('young', 'east'):0.06666666666666667
# ('american', 'child'):0.029411764705882353
# ('child', 'final'):0.0625
# ('see', 'someon'):0.0028653295128939827
# ('someon', 'look'):0.05
# ('superhero', 'beauti'):0.007462686567164179
# ('beauti', 'in'):0.006329113924050633
# ('forward', 'etern'):0.043478260869565216
# ('etern', 'next'):0.1
# ('marvel', 'carri'):0.0010141987829614604
# ('carri', 'includ'):0.0625
# ('includ', 'peopl'):0.04
# ('peopl', 'ethnic'):0.009259259259259259
# ('ethnic', 'render'):0.125
# ('render', 'sexual'):0.25
# ('sexual', 'identifi'):0.5
# ('identifi', 'cinematographi'):0.3333333333333333
# ('cinematographi', 'make'):0.013513513513513514
# ('make', 'masterpiec'):0.00390625
# ('masterpiec', 'realli'):0.05263157894736842
# ('charact', 'write'):0.0015625
# ('write', 'everyon'):0.02857142857142857
# ('everyon', 'movi'):0.023809523809523808
# ('easili', 'understand'):0.02564102564102564
# ('caus', 'motiv'):0.07692307692307693
# ('motiv', 'cours'):0.034482758620689655
# ('cours', 'way'):0.02564102564102564
# ('way', 'use'):0.005813953488372093
# ('languag', 'movi'):0.058823529411764705
# ('movi', 'fit'):0.0006807351940095302
# ('perfectli', 'pull'):0.03333333333333333
# ('pull', 'stori'):0.07142857142857142
# ('funni', 'visual'):0.00980392156862745
# ('visual', 'plea'):0.005291005291005291
# ('plea', 'enjoy'):0.037037037037037035
# ('move', 'liter'):0.0024390243902439024
# ('liter', 'everyth'):0.125
# ('everyth', 'hilari'):0.00980392156862745
# ('hilari', 'got'):0.05263157894736842
# ('got', 'crazi'):0.011904761904761904
# ('crazi', 'amount'):0.045454545454545456
# ('action', 'dragoon'):0.0019120458891013384
# ('dragoon', 'doesn'):0.037037037037037035
# ('doesn', 'like'):0.011235955056179775
# ('like', 'dragoon'):0.001851851851851852
# ('dragoon', 'love'):0.037037037037037035
# ('perfect', 'great'):0.010526315789473684
# ('1010', 'doubt'):0.045454545454545456
# ('doubt', 'dont'):0.06666666666666667
# ('know', 'miss'):0.007751937984496124
# ('miss', 'opinion'):0.022222222222222223
# ('you', 'undoubtedli'):0.0020876826722338203
# ('undoubtedli', 'movi'):0.2
# ('funni', 'way'):0.00980392156862745
# ('way', 'connect'):0.005813953488372093
# ('connect', 'storylin'):0.023809523809523808
# ('choreographi', 'chi'):0.007874015748031496
# ('chi', 'standard'):0.003125
# ('standard', 'stori'):0.045454545454545456
# ('line', 'superb'):0.024390243902439025
# ('you', 'keep'):0.0020876826722338203
# ('keep', 'comingc'):0.023255813953488372
# ('comingc', 'wait'):1.0
# ('chapter', 'work'):0.25
# ('effect', 'safe'):0.006711409395973154
# ('say', 'pleasantli'):0.005988023952095809
# ('surpris', 'watch'):0.0136986301369863
# ('shangchi', 'premier'):0.001976284584980237
# ('premier', 'point'):0.3333333333333333
# ('point', 'actual'):0.011235955056179775
# ('actual', 'watch'):0.013888888888888888
# ('full', 'film'):0.021739130434782608
# ('movi', 'foster'):0.0006807351940095302
# ('foster', 'fantast'):0.3333333333333333
# ('lie', 'hope'):0.006060606060606061
# ('hope', 'star'):0.012048192771084338
# ('film', 'charisma'):0.001059322033898305
# ('charisma', 'alon'):0.1
# ('reason', 'like'):0.03333333333333333
# ('movi', 'support'):0.0006807351940095302
# ('support', 'perform'):0.05555555555555555
# ('perform', 'weren'):0.010752688172043012
# ('weren', 'quit'):0.1
# ('quit', 'memor'):0.012345679012345678
# ('memor', 'cours'):0.07142857142857142
# ('cours', 'bad'):0.02564102564102564
# ('bad', 'usual'):0.008
# ('usual', 'visual'):0.009708737864077669
# ('great', 'might'):0.0019569471624266144
# ('might', 'had'):0.027777777777777776
# ('had', 'selfindulg'):0.25
# ('selfindulg', 'direct'):1.0
# ('cotton', 'excit'):0.017241379310344827
# ('shangchi', 'show'):0.001976284584980237
# ('show', 'next'):0.009433962264150943
# ('next', 'absolut'):0.016666666666666666
# ('screen', 'id'):0.011363636363636364
# ('say', 'moder'):0.005988023952095809
# ('moder', 'comedi'):0.5
# ('comedi', 'punch'):0.008771929824561403
# ('punch', 'action'):0.1
# ('action', 'kate'):0.0019120458891013384
# ('kate', 'heart'):0.013157894736842105
# ('heart', 'superb'):0.023255813953488372
# ('superb', 'far'):0.034482758620689655
# ('far', 'favourit'):0.0136986301369863
# ('wish', 'abil'):0.03225806451612903
# ('abil', 'forget'):0.07692307692307693
# ('forget', 'could'):0.1
# ('ring', 'and'):0.0044444444444444444
# ('and', 'you'):0.07142857142857142
# ('movi', 'return'):0.0006807351940095302
# ('return', 'cinema'):0.043478260869565216
# ('cinema', 'world'):0.0125
# ('way', 'get'):0.005813953488372093
# ('back', 'game'):0.010752688172043012
# ('game', 'mani'):0.07142857142857142
# ('mani', 'marvelmcu'):0.0070921985815602835
# ('marvelmcu', 'film'):1.0
# ('good', 'remark'):0.001838235294117647
# ('remark', 'factor'):0.1
# ('factor', 'cosmographi'):0.25
# ('cosmographi', 'actionfight'):0.5
# ('actionfight', 'sequenc'):1.0
# ('sequenc', 'fluid'):0.007575757575757576
# ('fluid', 'exagger'):0.16666666666666666
# ('exagger', 'soundtrack'):1.0
# ('soundtrack', 'anoth'):0.03333333333333333
# ('amaz', 'factor'):0.0048543689320388345
# ('factor', 'talk'):0.25
# ('talk', 'mixtur'):0.047619047619047616
# ('mixtur', 'cultur'):0.25
# ('cultur', 'realli'):0.008264462809917356
# ('realli', 'felt'):0.002793296089385475
# ('felt', 'black'):0.006802721088435374
# ('anoth', 'vice'):0.005681818181818182
# ('vice', 'one'):0.0625
# ('one', 'engag'):0.002150537634408602
# ('fan', 'regard'):0.00684931506849315
# ('regard', 'plot'):0.07142857142857142
# ('plot', 'one'):0.007751937984496124
# ('emot', 'lot'):0.008849557522123894
# ('heart', 'power'):0.023255813953488372
# ('power', 'chi'):0.013513513513513514
# ('point', 'biggest'):0.011235955056179775
# ('biggest', 'fear'):0.045454545454545456
# ('fear', 'sometim'):0.08333333333333333
# ('sometim', 'let'):0.03225806451612903
# ('let', 'you'):0.0196078431372549
# ('bad', 'sang'):0.008
# ('chi', 'along'):0.003125
# ('cast', 'lack'):0.0064516129032258064
# ('lack', 'good'):0.03333333333333333
# ('good', 'reliabl'):0.001838235294117647
# ('reliabl', 'act'):0.07142857142857142
# ('act', 'combin'):0.004524886877828055
# ('combin', 'signatur'):0.047619047619047616
# ('signatur', 'forc'):0.5
# ('forc', 'joke'):0.021739130434782608
# ('littl', 'annoy'):0.009708737864077669
# ('annoy', 'see'):0.045454545454545456
# ('see', 'although'):0.0028653295128939827
# ('simpl', 'littl'):0.07142857142857142
# ('predict', 'overal'):0.016129032258064516
# ('enjoy', 'final'):0.005154639175257732
# ('final', 'thought'):0.01098901098901099
# ('thought', 'despit'):0.012195121951219513
# ('despit', 'forc'):0.038461538461538464
# ('forc', 'act'):0.021739130434782608
# ('act', 'must'):0.004524886877828055
# ('definit', 'engag'):0.010416666666666666
# ('audienc', 'asset'):0.02040816326530612

# %% [markdown]
# **Noun phrases and relative probabilities of each review in terms of other reviews**

# %%
whole_dataset = ''
index = []
i = 1
for line in df['After Lemmatization']:
  whole_dataset = whole_dataset + line
  value = 'Review-' + str(i)
  index.append(value)
  i += 1

# %%
from textblob import TextBlob
noun_phrases = []
frequency = []
for line in df['After Lemmatization']:
  blob = TextBlob(line)
  for nouns in blob.noun_phrases:
    noun_phrases.append(nouns)
for word in noun_phrases:
  noun_phrases_freq = []
  for line in df['After Lemmatization']:
    noun_phrases_freq.append(line.count(word) / whole_dataset.count(word))
  frequency.append(noun_phrases_freq)
noun_phrases_df = pd.DataFrame(frequency).T
noun_phrases_df.columns = list(noun_phrases)
noun_phrases_df.index = index
noun_phrases_df
# Out:
#              cours rise tea  ...  movi definit engag audienc asset
# Review-1                0.0  ...                               0.0
# Review-2                0.0  ...                               0.0
# Review-3                0.0  ...                               0.0
# Review-4                1.0  ...                               0.0
# Review-5                0.0  ...                               0.0
# ...                     ...  ...                               ...
# Review-1146             0.0  ...                               0.0
# Review-1147             0.0  ...                               0.0
# Review-1148             0.0  ...                               0.0
# Review-1149             0.0  ...                               0.0
# Review-1150             0.0  ...                               1.0
#
# [1150 rows x 9545 columns]

# %% [markdown]
# # **Question 2: Undersand TF-IDF and Document representation**

# %% [markdown]
# (40 points). Starting from the documents (all the reviews, or abstracts, or tweets) collected for assignment two, write a python program:
#
# (1) To build the **documents-terms weights (tf*idf) matrix bold text**.
#
# (2) To rank the documents with respect to query (design a query by yourself, for example, "An Outstanding movie with a haunting performance and best character development") by using **cosine similarity**.

# %%
# Write your code here
import math
def tf_idf_value(sentence,word):
  size = len(sentence.split(" "))
  tf_value = sentence.count(word)/size
  idf_value = 0
  if(tf_value!=0):
    idf_value = math.log(size)/sentence.count(word)
  else:
    return 0;
  return tf_value*idf_value

sentences = df["Spelling Correction"].values.tolist()
tokens_list = set([j for i in sentences for j in i.split(" ")])
tf_idf = pd.DataFrame(tokens_list,columns=["token"])
count = 0
for i in sentences:
  tf_idf[str(count)] = tf_idf["token"].apply(lambda x : tf_idf_value(i,x))
  count+=1

tf_idf
# Out:
#                                                   token    0  ...  1148      1149
# 0                                                        0.0  ...   0.0  0.047162
# 1                                                  jobs  0.0  ...   0.0  0.000000
# 2                                               lighted  0.0  ...   0.0  0.000000
# 3                                               element  0.0  ...   0.0  0.000000
# 4                                                fodder  0.0  ...   0.0  0.000000
# ...                                                 ...  ...  ...   ...       ...
# 6616                                            avenues  0.0  ...   0.0  0.000000
# 6617                                          exclusive  0.0  ...   0.0  0.000000
# 6618                                                you  0.0  ...   0.0  0.047162
# 6619                                              sorts  0.0  ...   0.0  0.000000
# 6620  ______________________________________________...  0.0  ...   0.0  0.000000
#
# [6621 rows x 1151 columns]

# %%
from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
query_sentence = 'Shang-Chi and the Legend of the Ten Rings is an Action - Fantasy movie in which we watch a new era of Marvel Studios rise with Shang-Chi,the master of Kung Fu. He has to face his past involving him with the Ten Rings organization and crate his future accordingly.Finally, I have to say that "Shang-Chi and the Legend of the Ten Rings" is an amazing movie and I strongly recommend everyone to watch it, especially the fans of Marvel.'
X_list = word_tokenize(query_sentence)
sw = stopwords.words('english') 
X_set = {w for w in X_list if not w in sw}

# %%
def compute_vector(X_set, Y_set):
  rvector = X_set.union(Y_set)
  l1 =[];l2 =[]
  for w in rvector: 
      if w in X_set: l1.append(1)
      else: l1.append(0) 
      if w in Y_set: l2.append(1) 
      else: l2.append(0)
  return rvector, l1, l2

# %%
def compute_cosine(rvector, l1, l2):
  c = 0
  for i in range(len(rvector)): 
        c+= l1[i]*l2[i] 
  cosine = c / float((sum(l1)*sum(l2))**0.5) 
  return cosine

# %%
similarity_list = []
for sentence in df['Spelling Correction']:
  Y_list = word_tokenize(sentence)
  Y_set = {w for w in Y_list if not w in sw}
  rvector, l1, l2 = compute_vector(X_set, Y_set)
  try:
    similarity = compute_cosine(rvector, l1, l2)
  except ZeroDivisionError:
    similarity = 'None'
  similarity_list.append(similarity)
cosine_dataframe = pd.DataFrame(list(zip(df['Review'],similarity_list)), columns=['Reviews','Cosine Similarity'])
cosine_dataframe
# Out:
#                                                 Reviews Cosine Similarity
# 0                                                                    None
# 1                                                                    None
# 2                                                                    None
# 3     Of course I am just riffing off, teasing and m...         0.0412432
# 4     I was not expecting that, I had visions of a f...         0.0253673
# ...                                                 ...               ...
# 1145  Having worked on this film's visual effects, I...         0.0474579
# 1146  Absolutely fantastic! Just don't miss it on bi...         0.0424476
# 1147  By far my favourite Marvel Movie of all time. ...         0.0754314
# 1148                                                                 None
# 1149  Shang-Chi and the Legend of the Ten Rings is t...          0.055489
#
# [1150 rows x 2 columns]

# %% [markdown]
# # **Question 3: Create your own training and evaluation data for sentiment analysis**

# %% [markdown]
# (15 points). **You dodn't need to write program for this question!** Read each of the 500 review (if you collected the data from citeseer, you can think of other text classfication tasks instead of sentiment analysis) you collected in detail, and annotate each review with a sentiment (positive, negative, or neutral). Save the annotated dataset into a csv file with three columns (first column: document_id, clean_text, sentiment), upload the csv file to GitHub and submit the file link blew. This datset will be used for assignment four: sentiment analysis and text classification.

# %%
# The GitHub link of your final csv file

# Link: https://github.com/harithmote98/harith_INFO5731_Fall2021/blob/main/sentimentanalysis.csv
